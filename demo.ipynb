# %%
import json
import engine
import numpy as np
from num2words import num2words
from IPython.display import display
from PIL import Image
from pprint import pprint as print
from tqdm import tqdm

# %%
generator = engine.QGenerator()
data_prefix = 'val'
scenes = json.load(open(f'{data_prefix}_sceneGraphs.json', 'r'))
img_ids = set(json.load(open('valid_img_ids.json')))
scenes = {k: scenes[k] for k in list(scenes.keys()) for k in img_ids}

# %%
assert set(scenes.keys()) == img_ids

# %%
question_family = 'color_query'
question = json.load(open(f'question_families/{question_family}.json', 'r'))
program = question['program']
text_templates = question['templates']

# %%
question = json.load(open(f'question_families/{question_family}.json', 'r'))

# %%
print(question)
# Out:
# {'constraints': ['unique(obj1)', 'exclude_color(attrs1)'],
#  'name': 'color_query',
#  'program': ['color', ['scene', 'obj1', 'attrs1']],
#  'templates': ['What color is the <attrs1> <obj1>?'],
#  'tokens': ['obj1', 'attrs1', 'color1']}

# %%
print(question['templates'])
# Out:
# ['What color is the <attrs1> <obj1>?']

# %%
vocab = set(json.load(open('val_label_vocab.json')))

# %%
question
# Out:
# {'name': 'color_query',
#  'constraints': ['unique(obj1)', 'exclude_color(attrs1)'],
#  'program': ['color', ['scene', 'obj1', 'attrs1']],
#  'templates': ['What color is the <attrs1> <obj1>?'],
#  'tokens': ['obj1', 'attrs1', 'color1']}

# %%
# %%capture
# with open(f'{data_prefix}_{question_family}.txt', 'w+') as f:
d_names = ['question_id', 'img_id', 'label', 'sent']
bool_binary = {True: 'yes', False: 'no'}
all_questions = []
for img_id, scene in tqdm(scenes.items()):
#     qa_pairs = list(map(lambda x: dict(zip(d_names, (img_id, *x))), qa_pairs))
    for ix, (question_type, sent, answer) in enumerate(generator.generate_questions(scene, question)):
        q_id = str(img_id) + str(ix).zfill(9)
        answer_dict = {answer: 1.0}
        question_dict = {'img_id': img_id,
                         'label': answer_dict,
                         'question_id': q_id,
                         'sent': sent,
                         'question_type': question_type}
        all_questions.append(question_dict)

# %%
question_family = 'color_query_bool'
question = json.load(open(f'question_families/{question_family}.json', 'r'))
program = question['program']
text_templates = question['templates']

# %%
# %%capture
bool_binary = {True: 'yes', False: 'no'}
for img_id, scene in tqdm(scenes.items()):
#     qa_pairs = list(map(lambda x: dict(zip(d_names, (img_id, *x))), qa_pairs))
    for ix, (question_type, sent, answer) in enumerate(generator.generate_questions(scene, question)):
        q_id = str(img_id) + str(ix).zfill(9)
        answer_dict = {bool_binary[answer]: 1.0}
        question_dict = {'img_id': img_id,
                         'label': answer_dict,
                         'question_id': q_id,
                         'sent': sent,
                         'question_type': question_type}
        all_questions.append(question_dict)

# %%
json.dump(all_questions, open(f'{question_family}.json', 'w+'))

# %%
all_questions
# Out:
# [{'img_id': '2408684',
#   'label': {'brown': 1.0},
#   'question_id': '2408684000000000',
#   'sent': 'What color is the striped lying cat?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2408684',
#   'label': {'brown': 1.0},
#   'question_id': '2408684000000001',
#   'sent': 'What color is the resting cat?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2408684',
#   'label': {'brown': 1.0},
#   'question_id': '2408684000000002',
#   'sent': 'Is the furry upside down cat brown?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2408684',
#   'label': {'white': 1.0},
#   'question_id': '2408684000000003',
#   'sent': 'What color is the curtain?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2408684',
#   'label': {'brown': 1.0},
#   'question_id': '2408684000000004',
#   'sent': 'Is the resting striped cat brown?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2408684',
#   'label': {'brown': 1.0},
#   'question_id': '2408684000000005',
#   'sent': 'Is the resting furry upside down lying cat brown?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2408684',
#   'label': {'brown': 1.0},
#   'question_id': '2408684000000006',
#   'sent': 'Is the furry striped cat brown?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2408684',
#   'label': {'white': 1.0},
#   'question_id': '2408684000000007',
#   'sent': 'What color is the wall?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2408684',
#   'label': {'green': 1.0},
#   'question_id': '2408684000000008',
#   'sent': 'What color is the upside down eye?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2408684',
#   'label': {'brown': 1.0},
#   'question_id': '2408684000000009',
#   'sent': 'Is the upside down lying cat brown?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2408684',
#   'label': {'green': 1.0},
#   'question_id': '2408684000000010',
#   'sent': 'What color is the bright eye?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2408684',
#   'label': {'brown': 1.0},
#   'question_id': '2408684000000011',
#   'sent': 'What color is the resting furry cat?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2408684',
#   'label': {'brown': 1.0},
#   'question_id': '2408684000000012',
#   'sent': 'Is the resting upside down lying cat brown?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2408684',
#   'label': {'brown': 1.0},
#   'question_id': '2408684000000013',
#   'sent': 'What color is the upside down lying cat?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2408684',
#   'label': {'brown': 1.0},
#   'question_id': '2408684000000014',
#   'sent': 'What color is the striped upside down lying cat?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2408684',
#   'label': {'brown': 1.0},
#   'question_id': '2408684000000015',
#   'sent': 'Is the furry cat brown?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2408684',
#   'label': {'brown': 1.0},
#   'question_id': '2408684000000016',
#   'sent': 'What color is the resting furry upside down cat?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2408684',
#   'label': {'brown': 1.0},
#   'question_id': '2408684000000017',
#   'sent': 'Is the resting upside down striped cat brown?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2408684',
#   'label': {'brown': 1.0},
#   'question_id': '2408684000000018',
#   'sent': 'What color is the resting striped lying cat?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2408684',
#   'label': {'brown': 1.0},
#   'question_id': '2408684000000019',
#   'sent': 'What color is the resting striped furry lying cat?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2408684',
#   'label': {'brown': 1.0},
#   'question_id': '2408684000000020',
#   'sent': 'What color is the resting furry lying upside down striped cat?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2408684',
#   'label': {'green': 1.0},
#   'question_id': '2408684000000021',
#   'sent': 'What color is the eye?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2408684',
#   'label': {'brown': 1.0},
#   'question_id': '2408684000000022',
#   'sent': 'What color is the wood chair?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2408684',
#   'label': {'brown': 1.0},
#   'question_id': '2408684000000023',
#   'sent': 'Is the upside down striped cat brown?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2408684',
#   'label': {'brown': 1.0},
#   'question_id': '2408684000000024',
#   'sent': 'What color is the striped furry lying cat?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2408684',
#   'label': {'brown': 1.0},
#   'question_id': '2408684000000025',
#   'sent': 'Is the resting lying cat brown?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2408684',
#   'label': {'brown': 1.0},
#   'question_id': '2408684000000026',
#   'sent': 'What color is the furry lying cat?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2408684',
#   'label': {'brown': 1.0},
#   'question_id': '2408684000000027',
#   'sent': 'Is the lying cat brown?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2408684',
#   'label': {'brown': 1.0},
#   'question_id': '2408684000000028',
#   'sent': 'Is the wood chair brown?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2408684',
#   'label': {'brown': 1.0},
#   'question_id': '2408684000000029',
#   'sent': 'What color is the furry upside down cat?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2408684',
#   'label': {'brown': 1.0},
#   'question_id': '2408684000000030',
#   'sent': 'What color is the resting furry upside down striped cat?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2408684',
#   'label': {'green': 1.0},
#   'question_id': '2408684000000031',
#   'sent': 'Is the eye green?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2408684',
#   'label': {'pink': 1.0},
#   'question_id': '2408684000000032',
#   'sent': 'What color is the small nose?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2408684',
#   'label': {'brown': 1.0},
#   'question_id': '2408684000000033',
#   'sent': 'What color is the resting upside down lying cat?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2408684',
#   'label': {'brown': 1.0},
#   'question_id': '2408684000000034',
#   'sent': 'Is the resting striped furry lying cat brown?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2408684',
#   'label': {'brown': 1.0},
#   'question_id': '2408684000000035',
#   'sent': 'What color is the resting striped upside down lying cat?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2408684',
#   'label': {'brown': 1.0},
#   'question_id': '2408684000000036',
#   'sent': 'Is the striped cat brown?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2408684',
#   'label': {'brown': 1.0},
#   'question_id': '2408684000000037',
#   'sent': 'Is the resting furry lying cat brown?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2408684',
#   'label': {'brown': 1.0},
#   'question_id': '2408684000000038',
#   'sent': 'What color is the upside down striped cat?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2408684',
#   'label': {'pink': 1.0},
#   'question_id': '2408684000000039',
#   'sent': 'Is the ear pink?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2408684',
#   'label': {'brown': 1.0},
#   'question_id': '2408684000000040',
#   'sent': 'What color is the furry upside down striped cat?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2408684',
#   'label': {'brown': 1.0},
#   'question_id': '2408684000000041',
#   'sent': 'Is the furry upside down lying cat brown?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2408684',
#   'label': {'green': 1.0},
#   'question_id': '2408684000000042',
#   'sent': 'What color is the bright upside down eye?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2408684',
#   'label': {'brown': 1.0},
#   'question_id': '2408684000000043',
#   'sent': 'What color is the furry cat?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2408684',
#   'label': {'brown': 1.0},
#   'question_id': '2408684000000044',
#   'sent': 'What color is the resting striped cat?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2408684',
#   'label': {'brown': 1.0},
#   'question_id': '2408684000000045',
#   'sent': 'Is the resting striped upside down lying cat brown?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2408684',
#   'label': {'brown': 1.0},
#   'question_id': '2408684000000046',
#   'sent': 'Is the resting furry striped cat brown?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2408684',
#   'label': {'brown': 1.0},
#   'question_id': '2408684000000047',
#   'sent': 'Is the furry upside down striped cat brown?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2408684',
#   'label': {'brown': 1.0},
#   'question_id': '2408684000000048',
#   'sent': 'Is the resting furry upside down cat brown?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2408684',
#   'label': {'brown': 1.0},
#   'question_id': '2408684000000049',
#   'sent': 'Is the cat brown?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2408684',
#   'label': {'brown': 1.0},
#   'question_id': '2408684000000050',
#   'sent': 'Is the striped furry lying cat brown?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2408684',
#   'label': {'brown': 1.0},
#   'question_id': '2408684000000051',
#   'sent': 'What color is the furry striped cat?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2408684',
#   'label': {'brown': 1.0},
#   'question_id': '2408684000000052',
#   'sent': 'What color is the resting lying cat?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2408684',
#   'label': {'green': 1.0},
#   'question_id': '2408684000000053',
#   'sent': 'Is the upside down eye green?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2408684',
#   'label': {'white': 1.0},
#   'question_id': '2408684000000054',
#   'sent': 'Is the curtain white?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2408684',
#   'label': {'green': 1.0},
#   'question_id': '2408684000000055',
#   'sent': 'Is the bright eye green?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2408684',
#   'label': {'brown': 1.0},
#   'question_id': '2408684000000056',
#   'sent': 'Is the chair brown?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2408684',
#   'label': {'pink': 1.0},
#   'question_id': '2408684000000057',
#   'sent': 'What color is the ear?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2408684',
#   'label': {'brown': 1.0},
#   'question_id': '2408684000000058',
#   'sent': 'What color is the resting furry lying cat?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2408684',
#   'label': {'brown': 1.0},
#   'question_id': '2408684000000059',
#   'sent': 'What color is the striped cat?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2408684',
#   'label': {'brown': 1.0},
#   'question_id': '2408684000000060',
#   'sent': 'Is the resting furry upside down striped cat brown?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2408684',
#   'label': {'brown': 1.0},
#   'question_id': '2408684000000061',
#   'sent': 'What color is the upside down cat?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2408684',
#   'label': {'brown': 1.0},
#   'question_id': '2408684000000062',
#   'sent': 'Is the resting upside down cat brown?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2408684',
#   'label': {'white': 1.0},
#   'question_id': '2408684000000063',
#   'sent': 'Is the wall white?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2408684',
#   'label': {'pink': 1.0},
#   'question_id': '2408684000000064',
#   'sent': 'Is the small nose pink?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2408684',
#   'label': {'pink': 1.0},
#   'question_id': '2408684000000065',
#   'sent': 'What color is the nose?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2408684',
#   'label': {'brown': 1.0},
#   'question_id': '2408684000000066',
#   'sent': 'What color is the resting upside down striped cat?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2408684',
#   'label': {'brown': 1.0},
#   'question_id': '2408684000000067',
#   'sent': 'Is the resting striped lying cat brown?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2408684',
#   'label': {'pink': 1.0},
#   'question_id': '2408684000000068',
#   'sent': 'Is the nose pink?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2408684',
#   'label': {'brown': 1.0},
#   'question_id': '2408684000000069',
#   'sent': 'What color is the cat?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2408684',
#   'label': {'brown': 1.0},
#   'question_id': '2408684000000070',
#   'sent': 'Is the striped upside down lying cat brown?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2408684',
#   'label': {'brown': 1.0},
#   'question_id': '2408684000000071',
#   'sent': 'Is the striped lying cat brown?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2408684',
#   'label': {'brown': 1.0},
#   'question_id': '2408684000000072',
#   'sent': 'What color is the furry upside down lying cat?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2408684',
#   'label': {'green': 1.0},
#   'question_id': '2408684000000073',
#   'sent': 'Is the bright upside down eye green?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2408684',
#   'label': {'brown': 1.0},
#   'question_id': '2408684000000074',
#   'sent': 'What color is the chair?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2408684',
#   'label': {'brown': 1.0},
#   'question_id': '2408684000000075',
#   'sent': 'Is the resting furry cat brown?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2408684',
#   'label': {'brown': 1.0},
#   'question_id': '2408684000000076',
#   'sent': 'Is the striped furry upside down lying cat brown?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2408684',
#   'label': {'brown': 1.0},
#   'question_id': '2408684000000077',
#   'sent': 'What color is the resting upside down cat?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2408684',
#   'label': {'brown': 1.0},
#   'question_id': '2408684000000078',
#   'sent': 'Is the upside down cat brown?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2408684',
#   'label': {'brown': 1.0},
#   'question_id': '2408684000000079',
#   'sent': 'What color is the resting furry striped cat?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2408684',
#   'label': {'brown': 1.0},
#   'question_id': '2408684000000080',
#   'sent': 'What color is the lying cat?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2408684',
#   'label': {'brown': 1.0},
#   'question_id': '2408684000000081',
#   'sent': 'Is the furry lying cat brown?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2408684',
#   'label': {'brown': 1.0},
#   'question_id': '2408684000000082',
#   'sent': 'Is the resting cat brown?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2408684',
#   'label': {'brown': 1.0},
#   'question_id': '2408684000000083',
#   'sent': 'Is the resting furry lying upside down striped cat brown?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2408684',
#   'label': {'brown': 1.0},
#   'question_id': '2408684000000084',
#   'sent': 'What color is the resting furry upside down lying cat?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2408684',
#   'label': {'brown': 1.0},
#   'question_id': '2408684000000085',
#   'sent': 'What color is the striped furry upside down lying cat?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2397301',
#   'label': {'pink': 1.0},
#   'question_id': '2397301000000000',
#   'sent': 'What color is the cell phone?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2397301',
#   'label': {'pink': 1.0},
#   'question_id': '2397301000000001',
#   'sent': 'Is the cell phone pink?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2397301',
#   'label': {'blond': 1.0},
#   'question_id': '2397301000000002',
#   'sent': 'Is the hair blond?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2397301',
#   'label': {'blond': 1.0},
#   'question_id': '2397301000000003',
#   'sent': 'What color is the hair?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2388556',
#   'label': {'light brown': 1.0},
#   'question_id': '2388556000000000',
#   'sent': 'What color is the chair?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2388556',
#   'label': {'light brown': 1.0},
#   'question_id': '2388556000000001',
#   'sent': 'Is the empty chair light brown?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2388556',
#   'label': {'light brown': 1.0},
#   'question_id': '2388556000000002',
#   'sent': 'Is the chair light brown?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2388556',
#   'label': {'light brown': 1.0},
#   'question_id': '2388556000000003',
#   'sent': 'What color is the empty chair?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2388556',
#   'label': {'dark brown': 1.0},
#   'question_id': '2388556000000004',
#   'sent': 'Is the large table dark brown?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2388556',
#   'label': {'dark brown': 1.0},
#   'question_id': '2388556000000005',
#   'sent': 'Is the table dark brown?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2388556',
#   'label': {'dark brown': 1.0},
#   'question_id': '2388556000000006',
#   'sent': 'What color is the table?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2388556',
#   'label': {'dark brown': 1.0},
#   'question_id': '2388556000000007',
#   'sent': 'What color is the large table?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2379637',
#   'label': {'red': 1.0},
#   'question_id': '2379637000000000',
#   'sent': 'What color is the kite?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2379637',
#   'label': {'red': 1.0},
#   'question_id': '2379637000000001',
#   'sent': 'Is the kite red?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2379637',
#   'label': {'white': 1.0},
#   'question_id': '2379637000000002',
#   'sent': 'What color is the shirt?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2379637',
#   'label': {'black': 1.0},
#   'question_id': '2379637000000003',
#   'sent': 'Is the vehicle black?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2379637',
#   'label': {'blue': 1.0},
#   'question_id': '2379637000000004',
#   'sent': 'What color is the cloudy sky?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2379637',
#   'label': {'red': 1.0},
#   'question_id': '2379637000000005',
#   'sent': 'Is the large kite red?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2379637',
#   'label': {'blue': 1.0},
#   'question_id': '2379637000000006',
#   'sent': 'Is the sky blue?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2379637',
#   'label': {'blue': 1.0},
#   'question_id': '2379637000000007',
#   'sent': 'What color is the shorts?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2379637',
#   'label': {'blue': 1.0},
#   'question_id': '2379637000000008',
#   'sent': 'Is the cloudy sky blue?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2379637',
#   'label': {'black': 1.0},
#   'question_id': '2379637000000009',
#   'sent': 'What color is the vehicle?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2379637',
#   'label': {'brown': 1.0},
#   'question_id': '2379637000000010',
#   'sent': 'What color is the beach?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2379637',
#   'label': {'red': 1.0},
#   'question_id': '2379637000000011',
#   'sent': 'What color is the large kite?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2379637',
#   'label': {'white': 1.0},
#   'question_id': '2379637000000012',
#   'sent': 'Is the shirt white?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2379637',
#   'label': {'brown': 1.0},
#   'question_id': '2379637000000013',
#   'sent': 'Is the sandy beach brown?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2379637',
#   'label': {'blue': 1.0},
#   'question_id': '2379637000000014',
#   'sent': 'Is the shorts blue?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2379637',
#   'label': {'brown': 1.0},
#   'question_id': '2379637000000015',
#   'sent': 'Is the beach brown?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2379637',
#   'label': {'blue': 1.0},
#   'question_id': '2379637000000016',
#   'sent': 'What color is the sky?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2379637',
#   'label': {'brown': 1.0},
#   'question_id': '2379637000000017',
#   'sent': 'What color is the sandy beach?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2359504',
#   'label': {'blue': 1.0},
#   'question_id': '2359504000000000',
#   'sent': 'What color is the shirt?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2359504',
#   'label': {'blue': 1.0},
#   'question_id': '2359504000000001',
#   'sent': 'What color is the pants?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2359504',
#   'label': {'black': 1.0},
#   'question_id': '2359504000000002',
#   'sent': 'Is the upside down skateboard black?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2359504',
#   'label': {'black': 1.0},
#   'question_id': '2359504000000003',
#   'sent': 'Is the skateboard black?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2359504',
#   'label': {'black': 1.0},
#   'question_id': '2359504000000004',
#   'sent': 'What color is the upside down skateboard?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2359504',
#   'label': {'white': 1.0},
#   'question_id': '2359504000000005',
#   'sent': 'Is the wheels white?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2359504',
#   'label': {'blue': 1.0},
#   'question_id': '2359504000000006',
#   'sent': 'What color is the hat?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2359504',
#   'label': {'blue': 1.0},
#   'question_id': '2359504000000007',
#   'sent': 'Is the shirt blue?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2359504',
#   'label': {'white': 1.0},
#   'question_id': '2359504000000008',
#   'sent': 'What color is the wheels?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2359504',
#   'label': {'black': 1.0},
#   'question_id': '2359504000000009',
#   'sent': 'What color is the skateboard?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2359504',
#   'label': {'blue': 1.0},
#   'question_id': '2359504000000010',
#   'sent': 'Is the hat blue?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2359504',
#   'label': {'blue': 1.0},
#   'question_id': '2359504000000011',
#   'sent': 'Is the pants blue?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2397554',
#   'label': {'brown': 1.0},
#   'question_id': '2397554000000000',
#   'sent': 'Is the horse brown?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2397554',
#   'label': {'white': 1.0},
#   'question_id': '2397554000000001',
#   'sent': 'What color is the shirt?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2397554',
#   'label': {'brown': 1.0},
#   'question_id': '2397554000000002',
#   'sent': 'Is the hat brown?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2397554',
#   'label': {'blue': 1.0},
#   'question_id': '2397554000000003',
#   'sent': 'What color is the cloudy sky?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2397554',
#   'label': {'blue': 1.0},
#   'question_id': '2397554000000004',
#   'sent': 'Is the sky blue?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2397554',
#   'label': {'white': 1.0},
#   'question_id': '2397554000000005',
#   'sent': 'Is the shirt white?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2397554',
#   'label': {'blue': 1.0},
#   'question_id': '2397554000000006',
#   'sent': 'Is the water blue?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2397554',
#   'label': {'blue': 1.0},
#   'question_id': '2397554000000007',
#   'sent': 'Is the cloudy sky blue?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2397554',
#   'label': {'brown': 1.0},
#   'question_id': '2397554000000008',
#   'sent': 'What color is the horse?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2397554',
#   'label': {'white': 1.0},
#   'question_id': '2397554000000009',
#   'sent': 'What color is the clouds?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2397554',
#   'label': {'blue': 1.0},
#   'question_id': '2397554000000010',
#   'sent': 'What color is the water?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2397554',
#   'label': {'white': 1.0},
#   'question_id': '2397554000000011',
#   'sent': 'Is the clouds white?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2397554',
#   'label': {'blue': 1.0},
#   'question_id': '2397554000000012',
#   'sent': 'What color is the sky?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2397554',
#   'label': {'brown': 1.0},
#   'question_id': '2397554000000013',
#   'sent': 'What color is the hat?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2397554',
#   'label': {'brown': 1.0},
#   'question_id': '2397554000000014',
#   'sent': 'Is the hair brown?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2397554',
#   'label': {'brown': 1.0},
#   'question_id': '2397554000000015',
#   'sent': 'What color is the hair?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2338752',
#   'label': {'gray': 1.0},
#   'question_id': '2338752000000000',
#   'sent': 'What color is the tail?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2338752',
#   'label': {'gray': 1.0},
#   'question_id': '2338752000000001',
#   'sent': 'Is the long tail gray?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2338752',
#   'label': {'gray': 1.0},
#   'question_id': '2338752000000002',
#   'sent': 'What color is the long tail?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2338752',
#   'label': {'yellow': 1.0},
#   'question_id': '2338752000000003',
#   'sent': 'Is the eye yellow?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2338752',
#   'label': {'yellow': 1.0},
#   'question_id': '2338752000000004',
#   'sent': 'What color is the eye?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2338752',
#   'label': {'gray': 1.0},
#   'question_id': '2338752000000005',
#   'sent': 'Is the tail gray?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2384380',
#   'label': {'green': 1.0},
#   'question_id': '2384380000000000',
#   'sent': 'What color is the lush island?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2384380',
#   'label': {'green': 1.0},
#   'question_id': '2384380000000001',
#   'sent': 'What color is the island?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2384380',
#   'label': {'green': 1.0},
#   'question_id': '2384380000000002',
#   'sent': 'Is the island green?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2384380',
#   'label': {'green': 1.0},
#   'question_id': '2384380000000003',
#   'sent': 'Is the lush island green?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2413800',
#   'label': {'white': 1.0},
#   'question_id': '2413800000000000',
#   'sent': 'What color is the long large airplane?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2413800',
#   'label': {'blue': 1.0},
#   'question_id': '2413800000000001',
#   'sent': 'What color is the cloudy sky?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2413800',
#   'label': {'blue': 1.0},
#   'question_id': '2413800000000002',
#   'sent': 'Is the sky blue?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2413800',
#   'label': {'blue': 1.0},
#   'question_id': '2413800000000003',
#   'sent': 'Is the cloudy sky blue?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2413800',
#   'label': {'white': 1.0},
#   'question_id': '2413800000000004',
#   'sent': 'Is the large airplane white?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2413800',
#   'label': {'white': 1.0},
#   'question_id': '2413800000000005',
#   'sent': 'What color is the long airplane?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2413800',
#   'label': {'white': 1.0},
#   'question_id': '2413800000000006',
#   'sent': 'Is the airplane white?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2413800',
#   'label': {'white': 1.0},
#   'question_id': '2413800000000007',
#   'sent': 'Is the long airplane white?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2413800',
#   'label': {'blue': 1.0},
#   'question_id': '2413800000000008',
#   'sent': 'What color is the sky?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2413800',
#   'label': {'white': 1.0},
#   'question_id': '2413800000000009',
#   'sent': 'What color is the airplane?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2413800',
#   'label': {'white': 1.0},
#   'question_id': '2413800000000010',
#   'sent': 'Is the long large airplane white?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2413800',
#   'label': {'white': 1.0},
#   'question_id': '2413800000000011',
#   'sent': 'What color is the large airplane?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2352874',
#   'label': {'black': 1.0},
#   'question_id': '2352874000000000',
#   'sent': 'What color is the fence?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2352874',
#   'label': {'black': 1.0},
#   'question_id': '2352874000000001',
#   'sent': 'Is the fence black?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2413569',
#   'label': {'red': 1.0},
#   'question_id': '2413569000000000',
#   'sent': 'Is the bus red?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2413569',
#   'label': {'red': 1.0},
#   'question_id': '2413569000000001',
#   'sent': 'What color is the bus?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2375361',
#   'label': {'black': 1.0},
#   'question_id': '2375361000000000',
#   'sent': 'Is the table black?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2375361',
#   'label': {'black': 1.0},
#   'question_id': '2375361000000001',
#   'sent': 'What color is the table?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2373981',
#   'label': {'black': 1.0},
#   'question_id': '2373981000000000',
#   'sent': 'Is the shirt black?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2373981',
#   'label': {'black': 1.0},
#   'question_id': '2373981000000001',
#   'sent': 'What color is the cap?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2373981',
#   'label': {'brown': 1.0},
#   'question_id': '2373981000000002',
#   'sent': 'What color is the baseball leather glove?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2373981',
#   'label': {'brown': 1.0},
#   'question_id': '2373981000000003',
#   'sent': 'Is the leather glove brown?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2373981',
#   'label': {'gray': 1.0},
#   'question_id': '2373981000000004',
#   'sent': 'What color is the pants?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2373981',
#   'label': {'black': 1.0},
#   'question_id': '2373981000000005',
#   'sent': 'Is the cap black?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2373981',
#   'label': {'brown': 1.0},
#   'question_id': '2373981000000006',
#   'sent': 'What color is the baseball glove?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2373981',
#   'label': {'black': 1.0},
#   'question_id': '2373981000000007',
#   'sent': 'What color is the shirt?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2373981',
#   'label': {'brown': 1.0},
#   'question_id': '2373981000000008',
#   'sent': 'Is the baseball glove brown?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2373981',
#   'label': {'gray': 1.0},
#   'question_id': '2373981000000009',
#   'sent': 'Is the pants gray?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2373981',
#   'label': {'black': 1.0},
#   'question_id': '2373981000000010',
#   'sent': 'Is the baseball cap black?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2373981',
#   'label': {'black': 1.0},
#   'question_id': '2373981000000011',
#   'sent': 'What color is the baseball cap?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2373981',
#   'label': {'red': 1.0},
#   'question_id': '2373981000000012',
#   'sent': 'Is the face red?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2373981',
#   'label': {'brown': 1.0},
#   'question_id': '2373981000000013',
#   'sent': 'Is the glove brown?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2373981',
#   'label': {'brown': 1.0},
#   'question_id': '2373981000000014',
#   'sent': 'What color is the glove?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2373981',
#   'label': {'brown': 1.0},
#   'question_id': '2373981000000015',
#   'sent': 'What color is the leather glove?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2373981',
#   'label': {'red': 1.0},
#   'question_id': '2373981000000016',
#   'sent': 'What color is the face?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2373981',
#   'label': {'brown': 1.0},
#   'question_id': '2373981000000017',
#   'sent': 'Is the baseball leather glove brown?',
#   'question_type': 'color_query-1'},
#  {'img_id': '1159398',
#   'label': {'brown': 1.0},
#   'question_id': '1159398000000000',
#   'sent': 'Is the dirt brown?',
#   'question_type': 'color_query-1'},
#  {'img_id': '1159398',
#   'label': {'black': 1.0},
#   'question_id': '1159398000000001',
#   'sent': 'What color is the jacket?',
#   'question_type': 'color_query-0'},
#  {'img_id': '1159398',
#   'label': {'brown': 1.0},
#   'question_id': '1159398000000002',
#   'sent': 'What color is the dirt?',
#   'question_type': 'color_query-0'},
#  {'img_id': '1159398',
#   'label': {'black': 1.0},
#   'question_id': '1159398000000003',
#   'sent': 'Is the jacket black?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2406968',
#   'label': {'pink': 1.0},
#   'question_id': '2406968000000000',
#   'sent': 'What color is the shirt?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2406968',
#   'label': {'pink': 1.0},
#   'question_id': '2406968000000001',
#   'sent': 'Is the shirt pink?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2406968',
#   'label': {'black': 1.0},
#   'question_id': '2406968000000002',
#   'sent': 'What color is the metal fence?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2406968',
#   'label': {'yellow': 1.0},
#   'question_id': '2406968000000003',
#   'sent': 'Is the mirror yellow?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2406968',
#   'label': {'blue': 1.0},
#   'question_id': '2406968000000004',
#   'sent': 'What color is the bus?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2406968',
#   'label': {'blue': 1.0},
#   'question_id': '2406968000000005',
#   'sent': 'Is the parked bus blue?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2406968',
#   'label': {'blue': 1.0},
#   'question_id': '2406968000000006',
#   'sent': 'What color is the number?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2406968',
#   'label': {'black': 1.0},
#   'question_id': '2406968000000007',
#   'sent': 'What color is the post?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2406968',
#   'label': {'blue': 1.0},
#   'question_id': '2406968000000008',
#   'sent': 'Is the large bus blue?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2406968',
#   'label': {'blue': 1.0},
#   'question_id': '2406968000000009',
#   'sent': 'What color is the large bus?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2406968',
#   'label': {'yellow': 1.0},
#   'question_id': '2406968000000010',
#   'sent': 'What color is the mirror?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2406968',
#   'label': {'blue': 1.0},
#   'question_id': '2406968000000011',
#   'sent': 'Is the large parked bus blue?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2406968',
#   'label': {'blue': 1.0},
#   'question_id': '2406968000000012',
#   'sent': 'What color is the parked bus?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2406968',
#   'label': {'black': 1.0},
#   'question_id': '2406968000000013',
#   'sent': 'Is the metal fence black?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2406968',
#   'label': {'black': 1.0},
#   'question_id': '2406968000000014',
#   'sent': 'Is the post black?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2406968',
#   'label': {'black': 1.0},
#   'question_id': '2406968000000015',
#   'sent': 'Is the fence black?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2406968',
#   'label': {'blue': 1.0},
#   'question_id': '2406968000000016',
#   'sent': 'Is the bus blue?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2406968',
#   'label': {'blue': 1.0},
#   'question_id': '2406968000000017',
#   'sent': 'Is the number blue?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2406968',
#   'label': {'blue': 1.0},
#   'question_id': '2406968000000018',
#   'sent': 'What color is the large parked bus?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2406968',
#   'label': {'black': 1.0},
#   'question_id': '2406968000000019',
#   'sent': 'What color is the fence?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2349150',
#   'label': {'white': 1.0},
#   'question_id': '2349150000000000',
#   'sent': 'Is the logo white?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2349150',
#   'label': {'white': 1.0},
#   'question_id': '2349150000000001',
#   'sent': 'What color is the sign?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2349150',
#   'label': {'white': 1.0},
#   'question_id': '2349150000000002',
#   'sent': 'Is the sign white?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2349150',
#   'label': {'blue': 1.0},
#   'question_id': '2349150000000003',
#   'sent': 'Is the cap blue?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2349150',
#   'label': {'blue': 1.0},
#   'question_id': '2349150000000004',
#   'sent': 'What color is the cap?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2349150',
#   'label': {'white': 1.0},
#   'question_id': '2349150000000005',
#   'sent': 'What color is the logo?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2349150',
#   'label': {'black': 1.0},
#   'question_id': '2349150000000006',
#   'sent': 'Is the belt black?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2349150',
#   'label': {'brown': 1.0},
#   'question_id': '2349150000000007',
#   'sent': 'Is the glove brown?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2349150',
#   'label': {'brown': 1.0},
#   'question_id': '2349150000000008',
#   'sent': 'What color is the glove?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2349150',
#   'label': {'black': 1.0},
#   'question_id': '2349150000000009',
#   'sent': 'What color is the belt?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2374543',
#   'label': {'black': 1.0},
#   'question_id': '2374543000000000',
#   'sent': 'Is the shirt black?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2374543',
#   'label': {'black': 1.0},
#   'question_id': '2374543000000001',
#   'sent': 'Is the short shirt black?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2374543',
#   'label': {'blue': 1.0},
#   'question_id': '2374543000000002',
#   'sent': 'Is the denim jeans blue?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2374543',
#   'label': {'black': 1.0},
#   'question_id': '2374543000000003',
#   'sent': 'What color is the shirt?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2374543',
#   'label': {'blue': 1.0},
#   'question_id': '2374543000000004',
#   'sent': 'Is the jeans blue?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2374543',
#   'label': {'blue': 1.0},
#   'question_id': '2374543000000005',
#   'sent': 'What color is the jeans?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2374543',
#   'label': {'gray': 1.0},
#   'question_id': '2374543000000006',
#   'sent': 'What color is the bench?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2374543',
#   'label': {'gray': 1.0},
#   'question_id': '2374543000000007',
#   'sent': 'Is the wood bench gray?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2374543',
#   'label': {'black': 1.0},
#   'question_id': '2374543000000008',
#   'sent': 'What color is the short shirt?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2374543',
#   'label': {'gray': 1.0},
#   'question_id': '2374543000000009',
#   'sent': 'Is the bench gray?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2374543',
#   'label': {'green': 1.0},
#   'question_id': '2374543000000010',
#   'sent': 'Is the hat green?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2374543',
#   'label': {'blue': 1.0},
#   'question_id': '2374543000000011',
#   'sent': 'What color is the denim jeans?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2374543',
#   'label': {'gray': 1.0},
#   'question_id': '2374543000000012',
#   'sent': 'What color is the wood bench?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2374543',
#   'label': {'green': 1.0},
#   'question_id': '2374543000000013',
#   'sent': 'What color is the hat?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2382140',
#   'label': {'blue': 1.0},
#   'question_id': '2382140000000000',
#   'sent': 'What color is the sunny sky?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2382140',
#   'label': {'blue': 1.0},
#   'question_id': '2382140000000001',
#   'sent': 'Is the sunny sky blue?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2382140',
#   'label': {'blue': 1.0},
#   'question_id': '2382140000000002',
#   'sent': 'Is the sky blue?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2382140',
#   'label': {'blue': 1.0},
#   'question_id': '2382140000000003',
#   'sent': 'What color is the clear sky?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2382140',
#   'label': {'blue': 1.0},
#   'question_id': '2382140000000004',
#   'sent': 'What color is the ocean?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2382140',
#   'label': {'blue': 1.0},
#   'question_id': '2382140000000005',
#   'sent': 'Is the choppy ocean blue?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2382140',
#   'label': {'blue': 1.0},
#   'question_id': '2382140000000006',
#   'sent': 'What color is the clear sunny sky?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2382140',
#   'label': {'blue': 1.0},
#   'question_id': '2382140000000007',
#   'sent': 'What color is the choppy ocean?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2382140',
#   'label': {'blue': 1.0},
#   'question_id': '2382140000000008',
#   'sent': 'Is the ocean blue?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2382140',
#   'label': {'blue': 1.0},
#   'question_id': '2382140000000009',
#   'sent': 'What color is the sky?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2382140',
#   'label': {'blue': 1.0},
#   'question_id': '2382140000000010',
#   'sent': 'Is the clear sunny sky blue?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2382140',
#   'label': {'blue': 1.0},
#   'question_id': '2382140000000011',
#   'sent': 'Is the clear sky blue?',
#   'question_type': 'color_query-1'},
#  {'img_id': '713397',
#   'label': {'white': 1.0},
#   'question_id': '713397000000000',
#   'sent': 'What color is the desk?',
#   'question_type': 'color_query-0'},
#  {'img_id': '713397',
#   'label': {'white': 1.0},
#   'question_id': '713397000000001',
#   'sent': 'Is the desk white?',
#   'question_type': 'color_query-1'},
#  {'img_id': '713397',
#   'label': {'white': 1.0},
#   'question_id': '713397000000002',
#   'sent': 'Is the cup white?',
#   'question_type': 'color_query-1'},
#  {'img_id': '713397',
#   'label': {'brown': 1.0},
#   'question_id': '713397000000003',
#   'sent': 'Is the carpet brown?',
#   'question_type': 'color_query-1'},
#  {'img_id': '713397',
#   'label': {'white': 1.0},
#   'question_id': '713397000000004',
#   'sent': 'What color is the cup?',
#   'question_type': 'color_query-0'},
#  {'img_id': '713397',
#   'label': {'black': 1.0},
#   'question_id': '713397000000005',
#   'sent': 'What color is the chair?',
#   'question_type': 'color_query-0'},
#  {'img_id': '713397',
#   'label': {'brown': 1.0},
#   'question_id': '713397000000006',
#   'sent': 'What color is the carpet?',
#   'question_type': 'color_query-0'},
#  {'img_id': '713397',
#   'label': {'black': 1.0},
#   'question_id': '713397000000007',
#   'sent': 'Is the chair black?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2398196',
#   'label': {'green': 1.0},
#   'question_id': '2398196000000000',
#   'sent': 'Is the small bush green?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2398196',
#   'label': {'brown': 1.0},
#   'question_id': '2398196000000001',
#   'sent': 'What color is the grass?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2398196',
#   'label': {'green': 1.0},
#   'question_id': '2398196000000002',
#   'sent': 'Is the tall trees green?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2398196',
#   'label': {'brown': 1.0},
#   'question_id': '2398196000000003',
#   'sent': 'Is the short grass brown?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2398196',
#   'label': {'green': 1.0},
#   'question_id': '2398196000000004',
#   'sent': 'What color is the trees?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2398196',
#   'label': {'brown': 1.0},
#   'question_id': '2398196000000005',
#   'sent': 'Is the grass brown?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2398196',
#   'label': {'brown': 1.0},
#   'question_id': '2398196000000006',
#   'sent': 'What color is the dry grass?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2398196',
#   'label': {'gray': 1.0},
#   'question_id': '2398196000000007',
#   'sent': 'Is the rocks gray?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2398196',
#   'label': {'gray': 1.0},
#   'question_id': '2398196000000008',
#   'sent': 'What color is the decorative rocks?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2398196',
#   'label': {'blue': 1.0},
#   'question_id': '2398196000000009',
#   'sent': 'Is the sky blue?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2398196',
#   'label': {'gray': 1.0},
#   'question_id': '2398196000000010',
#   'sent': 'Is the large rocks gray?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2398196',
#   'label': {'brown': 1.0},
#   'question_id': '2398196000000011',
#   'sent': 'What color is the giraffes?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2398196',
#   'label': {'brown': 1.0},
#   'question_id': '2398196000000012',
#   'sent': 'Is the young lying giraffes brown?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2398196',
#   'label': {'brown': 1.0},
#   'question_id': '2398196000000013',
#   'sent': 'Is the dry short grass brown?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2398196',
#   'label': {'brown': 1.0},
#   'question_id': '2398196000000014',
#   'sent': 'Is the dry grass brown?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2398196',
#   'label': {'green': 1.0},
#   'question_id': '2398196000000015',
#   'sent': 'Is the trees green?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2398196',
#   'label': {'brown': 1.0},
#   'question_id': '2398196000000016',
#   'sent': 'Is the young giraffes brown?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2398196',
#   'label': {'gray': 1.0},
#   'question_id': '2398196000000017',
#   'sent': 'Is the decorative large rocks gray?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2398196',
#   'label': {'brown': 1.0},
#   'question_id': '2398196000000018',
#   'sent': 'What color is the short grass?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2398196',
#   'label': {'green': 1.0},
#   'question_id': '2398196000000019',
#   'sent': 'What color is the bush?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2398196',
#   'label': {'gray': 1.0},
#   'question_id': '2398196000000020',
#   'sent': 'What color is the decorative large rocks?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2398196',
#   'label': {'green': 1.0},
#   'question_id': '2398196000000021',
#   'sent': 'What color is the tall trees?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2398196',
#   'label': {'blue': 1.0},
#   'question_id': '2398196000000022',
#   'sent': 'What color is the sky?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2398196',
#   'label': {'green': 1.0},
#   'question_id': '2398196000000023',
#   'sent': 'Is the bush green?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2398196',
#   'label': {'gray': 1.0},
#   'question_id': '2398196000000024',
#   'sent': 'What color is the large rocks?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2398196',
#   'label': {'brown': 1.0},
#   'question_id': '2398196000000025',
#   'sent': 'What color is the young giraffes?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2398196',
#   'label': {'gray': 1.0},
#   'question_id': '2398196000000026',
#   'sent': 'Is the decorative rocks gray?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2398196',
#   'label': {'brown': 1.0},
#   'question_id': '2398196000000027',
#   'sent': 'Is the giraffes brown?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2398196',
#   'label': {'green': 1.0},
#   'question_id': '2398196000000028',
#   'sent': 'What color is the small bush?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2398196',
#   'label': {'brown': 1.0},
#   'question_id': '2398196000000029',
#   'sent': 'What color is the young lying giraffes?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2398196',
#   'label': {'brown': 1.0},
#   'question_id': '2398196000000030',
#   'sent': 'What color is the lying giraffes?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2398196',
#   'label': {'gray': 1.0},
#   'question_id': '2398196000000031',
#   'sent': 'What color is the rocks?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2398196',
# ...
#   'question_id': '2362189000000008',
#   'sent': 'What color is the long frame?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2362189',
#   'label': {'yellow': 1.0},
#   'question_id': '2362189000000009',
#   'sent': 'What color is the bananas?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2362189',
#   'label': {'brown': 1.0},
#   'question_id': '2362189000000010',
#   'sent': 'Is the bag brown?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2362189',
#   'label': {'white': 1.0},
#   'question_id': '2362189000000011',
#   'sent': 'Is the frame white?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2362189',
#   'label': {'yellow': 1.0},
#   'question_id': '2362189000000012',
#   'sent': 'Is the bananas yellow?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2362189',
#   'label': {'brown': 1.0},
#   'question_id': '2362189000000013',
#   'sent': 'What color is the paper bag?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2371084',
#   'label': {'yellow': 1.0},
#   'question_id': '2371084000000000',
#   'sent': 'What color is the open eyes?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2371084',
#   'label': {'pink': 1.0},
#   'question_id': '2371084000000001',
#   'sent': 'What color is the ear?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2371084',
#   'label': {'yellow': 1.0},
#   'question_id': '2371084000000002',
#   'sent': 'Is the eyes yellow?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2371084',
#   'label': {'white': 1.0},
#   'question_id': '2371084000000003',
#   'sent': 'Is the neck white?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2371084',
#   'label': {'green': 1.0},
#   'question_id': '2371084000000004',
#   'sent': 'Is the trees green?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2371084',
#   'label': {'gray': 1.0},
#   'question_id': '2371084000000005',
#   'sent': 'What color is the nose?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2371084',
#   'label': {'green': 1.0},
#   'question_id': '2371084000000006',
#   'sent': 'Is the leaves green?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2371084',
#   'label': {'gray': 1.0},
#   'question_id': '2371084000000007',
#   'sent': 'What color is the fur?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2371084',
#   'label': {'yellow': 1.0},
#   'question_id': '2371084000000008',
#   'sent': 'What color is the eyes?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2371084',
#   'label': {'white': 1.0},
#   'question_id': '2371084000000009',
#   'sent': 'What color is the neck?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2371084',
#   'label': {'green': 1.0},
#   'question_id': '2371084000000010',
#   'sent': 'What color is the trees?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2371084',
#   'label': {'gray': 1.0},
#   'question_id': '2371084000000011',
#   'sent': 'Is the fur gray?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2371084',
#   'label': {'pink': 1.0},
#   'question_id': '2371084000000012',
#   'sent': 'Is the ear pink?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2371084',
#   'label': {'green': 1.0},
#   'question_id': '2371084000000013',
#   'sent': 'What color is the leaves?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2371084',
#   'label': {'gray': 1.0},
#   'question_id': '2371084000000014',
#   'sent': 'Is the nose gray?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2371084',
#   'label': {'yellow': 1.0},
#   'question_id': '2371084000000015',
#   'sent': 'Is the open eyes yellow?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2371506',
#   'label': {'black': 1.0},
#   'question_id': '2371506000000000',
#   'sent': 'What color is the hour hand?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2371506',
#   'label': {'black': 1.0},
#   'question_id': '2371506000000001',
#   'sent': 'Is the clock black?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2371506',
#   'label': {'black': 1.0},
#   'question_id': '2371506000000002',
#   'sent': 'Is the hour hand black?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2371506',
#   'label': {'black': 1.0},
#   'question_id': '2371506000000003',
#   'sent': 'What color is the clock?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2371506',
#   'label': {'black': 1.0},
#   'question_id': '2371506000000004',
#   'sent': 'What color is the can?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2371506',
#   'label': {'black': 1.0},
#   'question_id': '2371506000000005',
#   'sent': 'Is the can black?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2385372',
#   'label': {'brown': 1.0},
#   'question_id': '2385372000000000',
#   'sent': 'Is the wet bench brown?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2385372',
#   'label': {'brown': 1.0},
#   'question_id': '2385372000000001',
#   'sent': 'Is the wood short fence brown?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2385372',
#   'label': {'brown': 1.0},
#   'question_id': '2385372000000002',
#   'sent': 'Is the dry wood wet bench brown?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2385372',
#   'label': {'green': 1.0},
#   'question_id': '2385372000000003',
#   'sent': 'Is the lush manicured bushes green?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2385372',
#   'label': {'brown': 1.0},
#   'question_id': '2385372000000004',
#   'sent': 'What color is the legs?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2385372',
#   'label': {'green': 1.0},
#   'question_id': '2385372000000005',
#   'sent': 'What color is the round bushes?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2385372',
#   'label': {'brown': 1.0},
#   'question_id': '2385372000000006',
#   'sent': 'Is the wood bench brown?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2385372',
#   'label': {'green': 1.0},
#   'question_id': '2385372000000007',
#   'sent': 'What color is the thick trees?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2385372',
#   'label': {'brown': 1.0},
#   'question_id': '2385372000000008',
#   'sent': 'What color is the short fence?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2385372',
#   'label': {'brown': 1.0},
#   'question_id': '2385372000000009',
#   'sent': 'What color is the wood fence?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2385372',
#   'label': {'green': 1.0},
#   'question_id': '2385372000000010',
#   'sent': 'What color is the trees?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2385372',
#   'label': {'brown': 1.0},
#   'question_id': '2385372000000011',
#   'sent': 'Is the wood legs brown?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2385372',
#   'label': {'brown': 1.0},
#   'question_id': '2385372000000012',
#   'sent': 'Is the fence brown?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2385372',
#   'label': {'black': 1.0},
#   'question_id': '2385372000000013',
#   'sent': 'Is the rope black?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2385372',
#   'label': {'green': 1.0},
#   'question_id': '2385372000000014',
#   'sent': 'What color is the post?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2385372',
#   'label': {'brown': 1.0},
#   'question_id': '2385372000000015',
#   'sent': 'What color is the bench?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2385372',
#   'label': {'white': 1.0},
#   'question_id': '2385372000000016',
#   'sent': 'What color is the snow?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2385372',
#   'label': {'gray': 1.0},
#   'question_id': '2385372000000017',
#   'sent': 'Is the rocks gray?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2385372',
#   'label': {'brown': 1.0},
#   'question_id': '2385372000000018',
#   'sent': 'What color is the wood legs?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2385372',
#   'label': {'brown': 1.0},
#   'question_id': '2385372000000019',
#   'sent': 'Is the short fence brown?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2385372',
#   'label': {'green': 1.0},
#   'question_id': '2385372000000020',
#   'sent': 'Is the bushes green?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2385372',
#   'label': {'brown': 1.0},
#   'question_id': '2385372000000021',
#   'sent': 'Is the log brown?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2385372',
#   'label': {'brown': 1.0},
#   'question_id': '2385372000000022',
#   'sent': 'What color is the dry bench?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2385372',
#   'label': {'brown': 1.0},
#   'question_id': '2385372000000023',
#   'sent': 'Is the bench brown?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2385372',
#   'label': {'green': 1.0},
#   'question_id': '2385372000000024',
#   'sent': 'What color is the lush manicured bushes?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2385372',
#   'label': {'brown': 1.0},
#   'question_id': '2385372000000025',
#   'sent': 'What color is the wood wet bench?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2385372',
#   'label': {'green': 1.0},
#   'question_id': '2385372000000026',
#   'sent': 'What color is the bushes?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2385372',
#   'label': {'brown': 1.0},
#   'question_id': '2385372000000027',
#   'sent': 'Is the dry bench brown?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2385372',
#   'label': {'brown': 1.0},
#   'question_id': '2385372000000028',
#   'sent': 'What color is the wood bench?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2385372',
#   'label': {'brown': 1.0},
#   'question_id': '2385372000000029',
#   'sent': 'What color is the log?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2385372',
#   'label': {'brown': 1.0},
#   'question_id': '2385372000000030',
#   'sent': 'What color is the wood short fence?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2385372',
#   'label': {'green': 1.0},
#   'question_id': '2385372000000031',
#   'sent': 'What color is the lush round manicured bushes?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2385372',
#   'label': {'green': 1.0},
#   'question_id': '2385372000000032',
#   'sent': 'Is the thick trees green?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2385372',
#   'label': {'brown': 1.0},
#   'question_id': '2385372000000033',
#   'sent': 'Is the wood wet bench brown?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2385372',
#   'label': {'brown': 1.0},
#   'question_id': '2385372000000034',
#   'sent': 'What color is the dry wood bench?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2385372',
#   'label': {'green': 1.0},
#   'question_id': '2385372000000035',
#   'sent': 'Is the trees green?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2385372',
#   'label': {'green': 1.0},
#   'question_id': '2385372000000036',
#   'sent': 'What color is the lush bushes?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2385372',
#   'label': {'brown': 1.0},
#   'question_id': '2385372000000037',
#   'sent': 'What color is the dry wet bench?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2385372',
#   'label': {'green': 1.0},
#   'question_id': '2385372000000038',
#   'sent': 'Is the manicured bushes green?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2385372',
#   'label': {'black': 1.0},
#   'question_id': '2385372000000039',
#   'sent': 'What color is the rope?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2385372',
#   'label': {'brown': 1.0},
#   'question_id': '2385372000000040',
#   'sent': 'What color is the dry wood wet bench?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2385372',
#   'label': {'brown': 1.0},
#   'question_id': '2385372000000041',
#   'sent': 'Is the dry wet bench brown?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2385372',
#   'label': {'brown': 1.0},
#   'question_id': '2385372000000042',
#   'sent': 'Is the legs brown?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2385372',
#   'label': {'green': 1.0},
#   'question_id': '2385372000000043',
#   'sent': 'Is the lush round manicured bushes green?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2385372',
#   'label': {'green': 1.0},
#   'question_id': '2385372000000044',
#   'sent': 'What color is the round manicured bushes?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2385372',
#   'label': {'green': 1.0},
#   'question_id': '2385372000000045',
#   'sent': 'Is the post green?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2385372',
#   'label': {'green': 1.0},
#   'question_id': '2385372000000046',
#   'sent': 'Is the round bushes green?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2385372',
#   'label': {'green': 1.0},
#   'question_id': '2385372000000047',
#   'sent': 'What color is the lush round bushes?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2385372',
#   'label': {'brown': 1.0},
#   'question_id': '2385372000000048',
#   'sent': 'Is the wood fence brown?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2385372',
#   'label': {'white': 1.0},
#   'question_id': '2385372000000049',
#   'sent': 'Is the snow white?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2385372',
#   'label': {'green': 1.0},
#   'question_id': '2385372000000050',
#   'sent': 'Is the lush bushes green?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2385372',
#   'label': {'brown': 1.0},
#   'question_id': '2385372000000051',
#   'sent': 'Is the dry wood bench brown?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2385372',
#   'label': {'green': 1.0},
#   'question_id': '2385372000000052',
#   'sent': 'What color is the manicured bushes?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2385372',
#   'label': {'brown': 1.0},
#   'question_id': '2385372000000053',
#   'sent': 'What color is the wet bench?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2385372',
#   'label': {'gray': 1.0},
#   'question_id': '2385372000000054',
#   'sent': 'What color is the rocks?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2385372',
#   'label': {'brown': 1.0},
#   'question_id': '2385372000000055',
#   'sent': 'What color is the fence?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2385372',
#   'label': {'green': 1.0},
#   'question_id': '2385372000000056',
#   'sent': 'Is the round manicured bushes green?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2385372',
#   'label': {'green': 1.0},
#   'question_id': '2385372000000057',
#   'sent': 'Is the lush round bushes green?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2395794',
#   'label': {'brown': 1.0},
#   'question_id': '2395794000000000',
#   'sent': 'Is the elephant brown?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2395794',
#   'label': {'green': 1.0},
#   'question_id': '2395794000000001',
#   'sent': 'Is the grass green?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2395794',
#   'label': {'brown': 1.0},
#   'question_id': '2395794000000002',
#   'sent': 'What color is the large elephant?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2395794',
#   'label': {'green': 1.0},
#   'question_id': '2395794000000003',
#   'sent': 'What color is the palm tree?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2395794',
#   'label': {'green': 1.0},
#   'question_id': '2395794000000004',
#   'sent': 'Is the large palm tree green?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2395794',
#   'label': {'green': 1.0},
#   'question_id': '2395794000000005',
#   'sent': 'What color is the grass?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2395794',
#   'label': {'green': 1.0},
#   'question_id': '2395794000000006',
#   'sent': 'Is the palm tree green?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2395794',
#   'label': {'brown': 1.0},
#   'question_id': '2395794000000007',
#   'sent': 'Is the large elephant brown?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2395794',
#   'label': {'green': 1.0},
#   'question_id': '2395794000000008',
#   'sent': 'What color is the large palm tree?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2395794',
#   'label': {'brown': 1.0},
#   'question_id': '2395794000000009',
#   'sent': 'What color is the elephant?',
#   'question_type': 'color_query-0'},
#  {'img_id': '2395794',
#   'label': {'gray': 1.0},
#   'question_id': '2395794000000010',
#   'sent': 'Is the rock gray?',
#   'question_type': 'color_query-1'},
#  {'img_id': '2395794',
#   'label': {'gray': 1.0},
#   'question_id': '2395794000000011',
#   'sent': 'What color is the rock?',
#   'question_type': 'color_query-0'},
#  ...]

# %%
import os

# %%
all_ans = set()
train_root = '../vqa_diag/questions1.2/val_all_questions.json'
# for file in os.listdir(train_root):
filename = f'{train_root}'
all_ans = all_ans.union({a['answer'] for a in json.load(open(filename)).values()})
print(f'{filename}: {len(all_ans)}')
# all_qs = json.load(open('../vqa_diag/questions1.2/train_all_questions/train_all_questions_0.json'))
# Out:
# '../vqa_diag/questions1.2/val_all_questions.json: 1501'

# %%
all_qs = json.load(open(filename))

# %%
all_qs
# Out:
# {'05451384': {'semantic': [{'operation': 'select',
#     'dependencies': [],
#     'argument': 'cat (1324563)'},
#    {'operation': 'filter color', 'dependencies': [0], 'argument': 'brown'},
#    {'operation': 'relate',
#     'dependencies': [1],
#     'argument': 'blanket,under,s (-)'},
#    {'operation': 'exist', 'dependencies': [2], 'argument': '?'}],
#   'entailed': ['05451386', '05451385'],
#   'equivalent': ['05451384'],
#   'question': 'Are there blankets under the brown cat?',
#   'imageId': '2382986',
#   'isBalanced': False,
#   'groups': {'global': None, 'local': '13-cat_blanket'},
#   'answer': 'no',
#   'semanticStr': 'select: cat (1324563)->filter color: brown [0]->relate: blanket,under,s (-) [1]->exist: ? [2]',
#   'annotations': {'answer': {},
#    'question': {'5:7': '1324563'},
#    'fullAnswer': {'4': '1324576', '7': '1324563'}},
#   'types': {'detailed': 'existRelSC',
#    'semantic': 'rel',
#    'structural': 'verify'},
#   'fullAnswer': 'No, there is a towel under the cat.'},
#  '05451385': {'semantic': [{'operation': 'select',
#     'dependencies': [],
#     'argument': 'bag (1324566)'},
#    {'operation': 'relate',
#     'dependencies': [0],
#     'argument': 'animal,to the right of,s (1324563)'},
#    {'operation': 'relate',
#     'dependencies': [1],
#     'argument': 'blanket,under,s (-)'},
#    {'operation': 'exist', 'dependencies': [2], 'argument': '?'}],
#   'entailed': ['05451386', '05451384'],
#   'equivalent': ['05451386', '05451385'],
#   'question': 'Do you see a blanket under the animal to the right of the bag?',
#   'imageId': '2382986',
#   'isBalanced': False,
#   'groups': {'global': None, 'local': '13-cat_blanket'},
#   'answer': 'no',
#   'semanticStr': 'select: bag (1324566)->relate: animal,to the right of,s (1324563) [0]->relate: blanket,under,s (-) [1]->exist: ? [2]',
#   'annotations': {'answer': {},
#    'question': {'13': '1324566', '7': '1324563'},
#    'fullAnswer': {'4': '1324576', '7': '1324563'}},
#   'types': {'detailed': 'existRelSC',
#    'semantic': 'rel',
#    'structural': 'verify'},
#   'fullAnswer': 'No, there is a towel under the cat.'},
#  '05451386': {'semantic': [{'operation': 'select',
#     'dependencies': [],
#     'argument': 'bag (1324566)'},
#    {'operation': 'relate',
#     'dependencies': [0],
#     'argument': 'animal,to the right of,s (1324563)'},
#    {'operation': 'relate',
#     'dependencies': [1],
#     'argument': 'blanket,under,s (-)'},
#    {'operation': 'exist', 'dependencies': [2], 'argument': '?'}],
#   'entailed': ['05451385', '05451384'],
#   'equivalent': ['05451386', '05451385'],
#   'question': 'Are there any blankets under the animal to the right of the bag?',
#   'imageId': '2382986',
#   'isBalanced': False,
#   'groups': {'global': None, 'local': '13-cat_blanket'},
#   'answer': 'no',
#   'semanticStr': 'select: bag (1324566)->relate: animal,to the right of,s (1324563) [0]->relate: blanket,under,s (-) [1]->exist: ? [2]',
#   'annotations': {'answer': {},
#    'question': {'12': '1324566', '6': '1324563'},
#    'fullAnswer': {'4': '1324576', '7': '1324563'}},
#   'types': {'detailed': 'existRelSC',
#    'semantic': 'rel',
#    'structural': 'verify'},
#   'fullAnswer': 'No, there is a towel under the cat.'},
#  '05451387': {'semantic': [{'operation': 'select',
#     'dependencies': [],
#     'argument': 'towel (1324576)'},
#    {'operation': 'filter color', 'dependencies': [0], 'argument': 'brown'},
#    {'operation': 'verify rel',
#     'dependencies': [1],
#     'argument': 'cat,under,o (1324563)'}],
#   'entailed': ['05451268', '05451267'],
#   'equivalent': ['05451387'],
#   'question': 'Is the brown towel under a cat?',
#   'imageId': '2382986',
#   'isBalanced': False,
#   'groups': {'global': None, 'local': '13-towel_cat'},
#   'answer': 'yes',
#   'semanticStr': 'select: towel (1324576)->filter color: brown [0]->verify rel: cat,under,o (1324563) [1]',
#   'annotations': {'answer': {},
#    'question': {'2:4': '1324576', '6': '1324563'},
#    'fullAnswer': {'2': '1324576', '6': '1324563'}},
#   'types': {'detailed': 'relVerify',
#    'semantic': 'rel',
#    'structural': 'verify'},
#   'fullAnswer': 'Yes, the towel is under a cat.'},
#  '05451380': {'semantic': [{'operation': 'select',
#     'dependencies': [],
#     'argument': 'sandwich (1324573)'},
#    {'operation': 'relate',
#     'dependencies': [0],
#     'argument': 'animal,to the left of,o (1324563)'},
#    {'operation': 'relate',
#     'dependencies': [1],
#     'argument': '_,under,s (1324576)'},
#    {'operation': 'query', 'dependencies': [2], 'argument': 'name'}],
#   'entailed': ['05451383', '05451382', '05451381', '05451379'],
#   'equivalent': ['05451380'],
#   'question': 'What is under the animal the sandwich is to the left of?',
#   'imageId': '2382986',
#   'isBalanced': False,
#   'groups': {'global': 'textile', 'local': '14-cat_under,s'},
#   'answer': 'towel',
#   'semanticStr': 'select: sandwich (1324573)->relate: animal,to the left of,o (1324563) [0]->relate: _,under,s (1324576) [1]->query: name [2]',
#   'annotations': {'answer': {'0': '1324576'},
#    'question': {'4': '1324563', '6': '1324573'},
#    'fullAnswer': {'1': '1324576', '5': '1324563'}},
#   'types': {'detailed': 'relS', 'semantic': 'rel', 'structural': 'query'},
#   'fullAnswer': 'The towel is under the cat.'},
#  '05451381': {'semantic': [{'operation': 'select',
#     'dependencies': [],
#     'argument': 'cat (1324563)'},
#    {'operation': 'relate',
#     'dependencies': [0],
#     'argument': '_,under,s (1324576)'},
#    {'operation': 'query', 'dependencies': [1], 'argument': 'name'}],
#   'entailed': ['05451383', '05451382', '05451380', '05451379'],
#   'equivalent': ['05451381'],
#   'question': 'What is under the cat?',
#   'imageId': '2382986',
#   'isBalanced': False,
#   'groups': {'global': 'textile', 'local': '14-cat_under,s'},
#   'answer': 'towel',
#   'semanticStr': 'select: cat (1324563)->relate: _,under,s (1324576) [0]->query: name [1]',
#   'annotations': {'answer': {'0': '1324576'},
#    'question': {},
#    'fullAnswer': {'1': '1324576', '5': '1324563'}},
#   'types': {'detailed': 'relS', 'semantic': 'rel', 'structural': 'query'},
#   'fullAnswer': 'The towel is under the cat.'},
#  '05451382': {'semantic': [{'operation': 'select',
#     'dependencies': [],
#     'argument': 'cat (1324563)'},
#    {'operation': 'filter color',
#     'dependencies': [0],
#     'argument': 'cream colored'},
#    {'operation': 'filter color', 'dependencies': [1], 'argument': 'white'},
#    {'operation': 'relate',
#     'dependencies': [2],
#     'argument': 'towel,under,s (1324576)'},
#    {'operation': 'exist', 'dependencies': [3], 'argument': '?'}],
#   'entailed': ['05451383'],
#   'equivalent': ['05451382'],
#   'question': 'Is there a towel under the cat that looks cream colored and white?',
#   'imageId': '2382986',
#   'isBalanced': False,
#   'groups': {'global': None, 'local': '13-cat_towel'},
#   'answer': 'yes',
#   'semanticStr': 'select: cat (1324563)->filter color: cream colored [0]->filter color: white [1]->relate: towel,under,s (1324576) [2]->exist: ? [3]',
#   'annotations': {'answer': {},
#    'question': {'3': '1324576',
#     '12': '1324563',
#     '9:11': '1324563',
#     '6': '1324563'},
#    'fullAnswer': {'4': '1324576', '7': '1324563'}},
#   'types': {'detailed': 'existRelS',
#    'semantic': 'rel',
#    'structural': 'verify'},
#   'fullAnswer': 'Yes, there is a towel under the cat.'},
#  '05451383': {'semantic': [{'operation': 'select',
#     'dependencies': [],
#     'argument': 'animal (1324563)'},
#    {'operation': 'filter color', 'dependencies': [0], 'argument': 'brown'},
#    {'operation': 'relate',
#     'dependencies': [1],
#     'argument': 'towel,under,s (1324576)'},
#    {'operation': 'exist', 'dependencies': [2], 'argument': '?'}],
#   'entailed': ['05451382'],
#   'equivalent': ['05451383'],
#   'question': 'Do you see any towels under the brown animal?',
#   'imageId': '2382986',
#   'isBalanced': False,
#   'groups': {'global': None, 'local': '13-cat_towel'},
#   'answer': 'yes',
#   'semanticStr': 'select: animal (1324563)->filter color: brown [0]->relate: towel,under,s (1324576) [1]->exist: ? [2]',
#   'annotations': {'answer': {},
#    'question': {'4': '1324576', '7:9': '1324563'},
#    'fullAnswer': {'4': '1324576', '7': '1324563'}},
#   'types': {'detailed': 'existRelS',
#    'semantic': 'rel',
#    'structural': 'verify'},
#   'fullAnswer': 'Yes, there is a towel under the cat.'},
#  '08369255': {'semantic': [{'operation': 'select',
#     'dependencies': [],
#     'argument': 'man (2527953)'},
#    {'operation': 'verify rel',
#     'dependencies': [0],
#     'argument': 'pants,wearing,o (1796037)'}],
#   'entailed': [],
#   'equivalent': ['08369255'],
#   'question': 'Is the man wearing trousers?',
#   'imageId': '2372640',
#   'isBalanced': False,
#   'groups': {'global': None, 'local': '13-man_pants'},
#   'answer': 'yes',
#   'semanticStr': 'select: man (2527953)->verify rel: pants,wearing,o (1796037) [0]',
#   'annotations': {'answer': {},
#    'question': {'2': '2527953', '4': '1796037'},
#    'fullAnswer': {'2': '2527953', '5': '1796037'}},
#   'types': {'detailed': 'relVerify',
#    'semantic': 'rel',
#    'structural': 'verify'},
#   'fullAnswer': 'Yes, the man is wearing trousers.'},
#  '08369254': {'semantic': [{'operation': 'select',
#     'dependencies': [],
#     'argument': 'pants (1796037)'},
#    {'operation': 'relate',
#     'dependencies': [0],
#     'argument': 'person,wearing,s (2527953)'},
#    {'operation': 'query', 'dependencies': [1], 'argument': 'name'}],
#   'entailed': ['08369253'],
#   'equivalent': ['08369254'],
#   'question': 'Who is wearing the pants?',
#   'imageId': '2372640',
#   'isBalanced': False,
#   'groups': {'global': 'person', 'local': '14-pants_wearing,s'},
#   'answer': 'man',
#   'semanticStr': 'select: pants (1796037)->relate: person,wearing,s (2527953) [0]->query: name [1]',
#   'annotations': {'answer': {'0': '2527953'},
#    'question': {},
#    'fullAnswer': {'1': '2527953', '4': '1796037'}},
#   'types': {'detailed': 'relS', 'semantic': 'rel', 'structural': 'query'},
#   'fullAnswer': 'The man is wearing pants.'},
#  '08369257': {'semantic': [{'operation': 'select',
#     'dependencies': [],
#     'argument': 'clock (-)'},
#    {'operation': 'exist', 'dependencies': [0], 'argument': '?'}],
#   'entailed': [],
#   'equivalent': ['08369257'],
#   'question': 'Is any clock visible there?',
#   'imageId': '2372640',
#   'isBalanced': False,
#   'groups': {'global': None, 'local': '03-clock'},
#   'answer': 'no',
#   'semanticStr': 'select: clock (-)->exist: ? [0]',
#   'annotations': {'answer': {}, 'question': {}, 'fullAnswer': {}},
#   'types': {'detailed': 'existC', 'semantic': 'obj', 'structural': 'verify'},
#   'fullAnswer': 'No, there are no clocks.'},
#  '08369256': {'semantic': [{'operation': 'select',
#     'dependencies': [],
#     'argument': 'man (2527953)'},
#    {'operation': 'verify rel',
#     'dependencies': [0],
#     'argument': 'eye glasses,wearing,o (-)'}],
#   'entailed': [],
#   'equivalent': ['08369256'],
#   'question': 'Is that man wearing eye glasses?',
#   'imageId': '2372640',
#   'isBalanced': False,
#   'groups': {'global': None, 'local': '13-man_eye glasses'},
#   'answer': 'no',
#   'semanticStr': 'select: man (2527953)->verify rel: eye glasses,wearing,o (-) [0]',
#   'annotations': {'answer': {},
#    'question': {'2': '2527953'},
#    'fullAnswer': {'2': '2527953', '5': '1796037'}},
#   'types': {'detailed': 'relVerifyCo',
#    'semantic': 'rel',
#    'structural': 'verify'},
#   'fullAnswer': 'No, the man is wearing trousers.'},
#  '08369251': {'semantic': [{'operation': 'select',
#     'dependencies': [],
#     'argument': 'man (2527953)'},
#    {'operation': 'verify rel',
#     'dependencies': [0],
#     'argument': 'backpack,wearing,o (1978710)'}],
#   'entailed': [],
#   'equivalent': ['08369251'],
#   'question': 'Is the man wearing a backpack?',
#   'imageId': '2372640',
#   'isBalanced': False,
#   'groups': {'global': None, 'local': '13-man_backpack'},
#   'answer': 'yes',
#   'semanticStr': 'select: man (2527953)->verify rel: backpack,wearing,o (1978710) [0]',
#   'annotations': {'answer': {},
#    'question': {'2': '2527953', '5': '1978710'},
#    'fullAnswer': {'2': '2527953', '6': '1978710'}},
#   'types': {'detailed': 'relVerify',
#    'semantic': 'rel',
#    'structural': 'verify'},
#   'fullAnswer': 'Yes, the man is wearing a backpack.'},
#  '05451389': {'semantic': [{'operation': 'select',
#     'dependencies': [],
#     'argument': 'bed (1324577)'},
#    {'operation': 'relate',
#     'dependencies': [0],
#     'argument': '_,on,s (1324576)'},
#    {'operation': 'query', 'dependencies': [1], 'argument': 'name'}],
#   'entailed': ['05451390'],
#   'equivalent': ['05451389'],
#   'question': 'What is on the bed?',
#   'imageId': '2382986',
#   'isBalanced': False,
#   'groups': {'global': 'textile', 'local': '14-bed_on,s'},
#   'answer': 'towel',
#   'semanticStr': 'select: bed (1324577)->relate: _,on,s (1324576) [0]->query: name [1]',
#   'annotations': {'answer': {'0': '1324576'},
#    'question': {},
#    'fullAnswer': {'1': '1324576', '5': '1324577'}},
#   'types': {'detailed': 'relS', 'semantic': 'rel', 'structural': 'query'},
#   'fullAnswer': 'The towel is on the bed.'},
#  '08369253': {'semantic': [{'operation': 'select',
#     'dependencies': [],
#     'argument': 'pants (1796037)'},
#    {'operation': 'relate',
#     'dependencies': [0],
#     'argument': 'person,wearing,s (2527953)'},
#    {'operation': 'query', 'dependencies': [1], 'argument': 'name'}],
#   'entailed': ['08369254'],
#   'equivalent': ['08369253'],
#   'question': 'Who is wearing pants?',
#   'imageId': '2372640',
#   'isBalanced': True,
#   'groups': {'global': 'person', 'local': '14-pants_wearing,s'},
#   'answer': 'man',
#   'semanticStr': 'select: pants (1796037)->relate: person,wearing,s (2527953) [0]->query: name [1]',
#   'annotations': {'answer': {'0': '2527953'},
#    'question': {'3': '1796037'},
#    'fullAnswer': {'1': '2527953', '4': '1796037'}},
#   'types': {'detailed': 'relS', 'semantic': 'rel', 'structural': 'query'},
#   'fullAnswer': 'The man is wearing pants.'},
#  '08369252': {'semantic': [{'operation': 'select',
#     'dependencies': [],
#     'argument': 'man (2527953)'},
#    {'operation': 'verify rel',
#     'dependencies': [0],
#     'argument': 'watch,wearing,o (-)'}],
#   'entailed': [],
#   'equivalent': ['08369252'],
#   'question': 'Is the man wearing a watch?',
#   'imageId': '2372640',
#   'isBalanced': False,
#   'groups': {'global': None, 'local': '13-man_watch'},
#   'answer': 'no',
#   'semanticStr': 'select: man (2527953)->verify rel: watch,wearing,o (-) [0]',
#   'annotations': {'answer': {},
#    'question': {'2': '2527953'},
#    'fullAnswer': {'2': '2527953', '6': '1978710'}},
#   'types': {'detailed': 'relVerifyCo',
#    'semantic': 'rel',
#    'structural': 'verify'},
#   'fullAnswer': 'No, the man is wearing a backpack.'},
#  '12344534': {'semantic': [{'operation': 'select',
#     'dependencies': [],
#     'argument': 'scene'},
#    {'operation': 'query', 'dependencies': [0], 'argument': 'place'}],
#   'entailed': ['12344533', '12344535'],
#   'equivalent': ['12344533', '12344534'],
#   'question': 'What place could this be?',
#   'imageId': '2399672',
#   'isBalanced': False,
#   'groups': {'global': 'road', 'local': '02q-place'},
#   'answer': 'sidewalk',
#   'semanticStr': 'select: scene->query: place [0]',
#   'annotations': {'answer': {}, 'question': {}, 'fullAnswer': {}},
#   'types': {'detailed': 'place', 'semantic': 'global', 'structural': 'query'},
#   'fullAnswer': 'It is a sidewalk.'},
#  '12344535': {'semantic': [{'operation': 'select',
#     'dependencies': [],
#     'argument': 'scene'},
#    {'operation': 'query', 'dependencies': [0], 'argument': 'place'}],
#   'entailed': ['12344533', '12344534'],
#   'equivalent': ['12344535'],
#   'question': 'Which place is it?',
#   'imageId': '2399672',
#   'isBalanced': False,
#   'groups': {'global': 'road', 'local': '02q-place'},
#   'answer': 'sidewalk',
#   'semanticStr': 'select: scene->query: place [0]',
#   'annotations': {'answer': {}, 'question': {}, 'fullAnswer': {}},
#   'types': {'detailed': 'place', 'semantic': 'global', 'structural': 'query'},
#   'fullAnswer': 'It is a sidewalk.'},
#  '12344536': {'semantic': [{'operation': 'select',
#     'dependencies': [],
#     'argument': 'person (1167549,1167536,1167544,1167551)'},
#    {'operation': 'same', 'dependencies': [0], 'argument': 'gender'}],
#   'entailed': [],
#   'equivalent': ['12344536'],
#   'question': 'Are these people female?',
#   'imageId': '2399672',
#   'isBalanced': False,
#   'groups': {'global': None, 'local': '07same-allpeople'},
#   'answer': 'no',
#   'semanticStr': 'select: person (1167549,1167536,1167544,1167551)->same: gender [0]',
#   'annotations': {'answer': {}, 'question': {}, 'fullAnswer': {}},
#   'types': {'detailed': 'sameGenderC',
#    'semantic': 'attr',
#    'structural': 'compare'},
#   'fullAnswer': 'No, they are both male and female.'},
#  '12344537': {'semantic': [{'operation': 'select',
#     'dependencies': [],
#     'argument': 'person (1167549,1167536,1167544,1167551)'},
#    {'operation': 'different', 'dependencies': [0], 'argument': 'gender'}],
#   'entailed': [],
#   'equivalent': ['12344537'],
#   'question': 'Are these people different genders?',
#   'imageId': '2399672',
#   'isBalanced': False,
#   'groups': {'global': None, 'local': '07different-allpeople'},
#   'answer': 'no',
#   'semanticStr': 'select: person (1167549,1167536,1167544,1167551)->different: gender [0]',
#   'annotations': {'answer': {}, 'question': {}, 'fullAnswer': {}},
#   'types': {'detailed': 'diffGender',
#    'semantic': 'attr',
#    'structural': 'compare'},
#   'fullAnswer': 'No, they are both male and female.'},
#  '11414719': {'semantic': [{'operation': 'select',
#     'dependencies': [],
#     'argument': 'bus (2785222)'},
#    {'operation': 'query', 'dependencies': [0], 'argument': 'size'}],
#   'entailed': ['11414717',
#    '11414716',
#    '11414715',
#    '11414714',
#    '11414713',
#    '11414712',
#    '11414710',
#    '11414731',
#    '11414718',
#    '11414733',
#    '11414736',
#    '11414734',
#    '11414724',
#    '11414732',
#    '11414722',
#    '11414723',
#    '11414720',
#    '11414721'],
#   'equivalent': ['11414719'],
#   'question': 'How large is the bus?',
#   'imageId': '2415503',
#   'isBalanced': False,
#   'groups': {'global': 'size', 'local': '10q-bus_size'},
#   'answer': 'large',
#   'semanticStr': 'select: bus (2785222)->query: size [0]',
#   'annotations': {'answer': {},
#    'question': {'4': '2785222'},
#    'fullAnswer': {'1': '2785222'}},
#   'types': {'detailed': 'how', 'semantic': 'attr', 'structural': 'query'},
#   'fullAnswer': 'The bus is large.'},
#  '11414718': {'semantic': [{'operation': 'select',
#     'dependencies': [],
#     'argument': 'vehicle (2785222)'},
#    {'operation': 'filter color', 'dependencies': [0], 'argument': 'green'},
#    {'operation': 'query', 'dependencies': [1], 'argument': 'size'}],
#   'entailed': ['11414717',
#    '11414716',
#    '11414715',
#    '11414714',
#    '11414713',
#    '11414712',
#    '11414710',
#    '11414731',
#    '11414719',
#    '11414733',
#    '11414736',
#    '11414734',
#    '11414724',
#    '11414732',
#    '11414722',
#    '11414723',
#    '11414720',
#    '11414721'],
#   'equivalent': ['11414718'],
#   'question': 'What is the size of the green vehicle?',
#   'imageId': '2415503',
#   'isBalanced': False,
#   'groups': {'global': 'size', 'local': '10q-bus_size'},
#   'answer': 'large',
#   'semanticStr': 'select: vehicle (2785222)->filter color: green [0]->query: size [1]',
#   'annotations': {'answer': {},
#    'question': {'6:8': '2785222'},
#    'fullAnswer': {'1': '2785222'}},
#   'types': {'detailed': 'directOf', 'semantic': 'attr', 'structural': 'query'},
#   'fullAnswer': 'The bus is large.'},
#  '11414717': {'semantic': [{'operation': 'select',
#     'dependencies': [],
#     'argument': 'bus (2785222)'},
#    {'operation': 'query', 'dependencies': [0], 'argument': 'size'}],
#   'entailed': ['11414716',
#    '11414715',
#    '11414714',
#    '11414713',
#    '11414712',
#    '11414710',
#    '11414731',
#    '11414719',
#    '11414718',
#    '11414733',
#    '11414736',
#    '11414734',
#    '11414724',
#    '11414732',
#    '11414722',
#    '11414723',
#    '11414720',
#    '11414721'],
#   'equivalent': ['11414717', '11414716'],
#   'question': 'What size is the bus?',
#   'imageId': '2415503',
#   'isBalanced': False,
#   'groups': {'global': 'size', 'local': '10q-bus_size'},
#   'answer': 'large',
#   'semanticStr': 'select: bus (2785222)->query: size [0]',
#   'annotations': {'answer': {},
#    'question': {'4': '2785222'},
#    'fullAnswer': {'1': '2785222'}},
#   'types': {'detailed': 'directOf', 'semantic': 'attr', 'structural': 'query'},
#   'fullAnswer': 'The bus is large.'},
#  '11414716': {'semantic': [{'operation': 'select',
#     'dependencies': [],
#     'argument': 'bus (2785222)'},
#    {'operation': 'query', 'dependencies': [0], 'argument': 'size'}],
#   'entailed': ['11414717',
#    '11414715',
#    '11414714',
#    '11414713',
#    '11414712',
#    '11414710',
#    '11414731',
#    '11414719',
#    '11414718',
#    '11414733',
#    '11414736',
#    '11414734',
#    '11414724',
#    '11414732',
#    '11414722',
#    '11414723',
#    '11414720',
#    '11414721'],
#   'equivalent': ['11414717', '11414716'],
#   'question': 'What is the size of the bus?',
#   'imageId': '2415503',
#   'isBalanced': False,
#   'groups': {'global': 'size', 'local': '10q-bus_size'},
#   'answer': 'large',
#   'semanticStr': 'select: bus (2785222)->query: size [0]',
#   'annotations': {'answer': {},
#    'question': {'6': '2785222'},
#    'fullAnswer': {'1': '2785222'}},
#   'types': {'detailed': 'directOf', 'semantic': 'attr', 'structural': 'query'},
#   'fullAnswer': 'The bus is large.'},
#  '11414715': {'semantic': [{'operation': 'select',
#     'dependencies': [],
#     'argument': 'vehicle (2785222)'},
#    {'operation': 'filter color', 'dependencies': [0], 'argument': 'green'},
#    {'operation': 'verify size', 'dependencies': [1], 'argument': 'large'}],
#   'entailed': ['11414717',
#    '11414716',
#    '11414714',
#    '11414713',
#    '11414712',
#    '11414710',
#    '11414731',
#    '11414719',
#    '11414718',
#    '11414720',
#    '11414736',
#    '11414734',
#    '11414724',
#    '11414732',
#    '11414722',
#    '11414723',
#    '11414733',
#    '11414721'],
#   'equivalent': ['11414715'],
#   'question': 'Does the green vehicle look large?',
#   'imageId': '2415503',
#   'isBalanced': False,
#   'groups': {'global': None, 'local': '06-bus_large'},
#   'answer': 'yes',
#   'semanticStr': 'select: vehicle (2785222)->filter color: green [0]->verify size: large [1]',
#   'annotations': {'answer': {},
#    'question': {'2:4': '2785222'},
#    'fullAnswer': {'2': '2785222'}},
#   'types': {'detailed': 'verifyAttrK',
#    'semantic': 'attr',
#    'structural': 'verify'},
#   'fullAnswer': 'Yes, the bus is large.'},
#  '11414714': {'semantic': [{'operation': 'select',
#     'dependencies': [],
#     'argument': 'bus (2785222)'},
#    {'operation': 'verify size', 'dependencies': [0], 'argument': 'large'}],
#   'entailed': ['11414717',
#    '11414716',
#    '11414715',
#    '11414713',
#    '11414712',
#    '11414710',
#    '11414731',
#    '11414719',
#    '11414718',
#    '11414720',
#    '11414736',
#    '11414734',
#    '11414724',
#    '11414732',
#    '11414722',
#    '11414723',
#    '11414733',
#    '11414721'],
#   'equivalent': ['11414714', '11414713'],
#   'question': 'Does the bus have large size?',
#   'imageId': '2415503',
#   'isBalanced': False,
#   'groups': {'global': None, 'local': '06-bus_large'},
#   'answer': 'yes',
#   'semanticStr': 'select: bus (2785222)->verify size: large [0]',
#   'annotations': {'answer': {},
#    'question': {'2': '2785222'},
#    'fullAnswer': {'2': '2785222'}},
#   'types': {'detailed': 'verifyAttrK',
#    'semantic': 'attr',
#    'structural': 'verify'},
#   'fullAnswer': 'Yes, the bus is large.'},
#  '11414713': {'semantic': [{'operation': 'select',
#     'dependencies': [],
#     'argument': 'bus (2785222)'},
#    {'operation': 'verify size', 'dependencies': [0], 'argument': 'large'}],
#   'entailed': ['11414717',
#    '11414716',
#    '11414715',
#    '11414714',
#    '11414712',
#    '11414710',
#    '11414731',
#    '11414719',
#    '11414718',
#    '11414720',
#    '11414736',
#    '11414734',
#    '11414724',
#    '11414732',
#    '11414722',
#    '11414723',
#    '11414733',
#    '11414721'],
#   'equivalent': ['11414714', '11414713'],
#   'question': 'Does the bus look large?',
#   'imageId': '2415503',
#   'isBalanced': False,
#   'groups': {'global': None, 'local': '06-bus_large'},
#   'answer': 'yes',
#   'semanticStr': 'select: bus (2785222)->verify size: large [0]',
#   'annotations': {'answer': {},
#    'question': {'2': '2785222'},
#    'fullAnswer': {'2': '2785222'}},
#   'types': {'detailed': 'verifyAttrK',
#    'semantic': 'attr',
#    'structural': 'verify'},
#   'fullAnswer': 'Yes, the bus is large.'},
#  '11414712': {'semantic': [{'operation': 'select',
#     'dependencies': [],
#     'argument': 'bus (2785222)'},
#    {'operation': 'verify size', 'dependencies': [0], 'argument': 'large'}],
#   'entailed': ['11414717',
#    '11414716',
#    '11414715',
#    '11414714',
#    '11414713',
#    '11414710',
#    '11414731',
#    '11414719',
#    '11414718',
#    '11414720',
#    '11414736',
#    '11414734',
#    '11414724',
#    '11414732',
#    '11414722',
#    '11414723',
#    '11414733',
#    '11414721'],
#   'equivalent': ['11414712'],
#   'question': 'Do you think that bus is large?',
#   'imageId': '2415503',
#   'isBalanced': False,
#   'groups': {'global': None, 'local': '06-bus_large'},
#   'answer': 'yes',
#   'semanticStr': 'select: bus (2785222)->verify size: large [0]',
#   'annotations': {'answer': {},
#    'question': {'4': '2785222'},
#    'fullAnswer': {'2': '2785222'}},
#   'types': {'detailed': 'verifyAttr',
#    'semantic': 'attr',
#    'structural': 'verify'},
#   'fullAnswer': 'Yes, the bus is large.'},
#  '11414711': {'semantic': [{'operation': 'select',
#     'dependencies': [],
#     'argument': 'bus (2785222)'},
#    {'operation': 'filter size', 'dependencies': [0], 'argument': 'not(large)'},
#    {'operation': 'exist', 'dependencies': [1], 'argument': '?'},
#    {'operation': 'select', 'dependencies': [], 'argument': 'truck (-) '},
#    {'operation': 'filter size', 'dependencies': [3], 'argument': 'not(large)'},
#    {'operation': 'exist', 'dependencies': [4], 'argument': '?'},
#    {'operation': 'or', 'dependencies': [2, 5], 'argument': ''}],
#   'entailed': ['11414727', '11414730', '11414728', '11414729'],
#   'equivalent': ['11414711'],
#   'question': 'Are there trucks or buses that are not large?',
#   'imageId': '2415503',
#   'isBalanced': False,
#   'groups': {'global': None, 'local': '04-bus_n#large'},
#   'answer': 'no',
#   'semanticStr': 'select: bus (2785222)->filter size: not(large) [0]->exist: ? [1]->select: truck (-) ->filter size: not(large) [3]->exist: ? [4]->or:  [2, 5]',
#   'annotations': {'answer': {},
#    'question': {'4': '2785222'},
#    'fullAnswer': {'4': '2785222'}},
#   'types': {'detailed': 'existThatOrC',
#    'semantic': 'obj',
#    'structural': 'logical'},
#   'fullAnswer': 'No, there is a bus but it is large.'},
#  '11414710': {'semantic': [{'operation': 'select',
#     'dependencies': [],
#     'argument': 'bus (2785222)'},
#    {'operation': 'verify size', 'dependencies': [0], 'argument': 'large'},
#    {'operation': 'verify color', 'dependencies': [0], 'argument': 'white '},
#    {'operation': 'and', 'dependencies': [1, 2], 'argument': ''}],
#   'entailed': [],
#   'equivalent': ['11414710'],
#   'question': 'Is the bus large and white?',
#   'imageId': '2415503',
#   'isBalanced': False,
#   'groups': {'global': None, 'local': '05-large_white'},
#   'answer': 'no',
#   'semanticStr': 'select: bus (2785222)->verify size: large [0]->verify color: white  [0]->and:  [1, 2]',
#   'annotations': {'answer': {},
#    'question': {'2': '2785222'},
#    'fullAnswer': {'2': '2785222'}},
#   'types': {'detailed': 'verifyAttrsC',
#    'semantic': 'attr',
#    'structural': 'logical'},
#   'fullAnswer': 'No, the bus is large but green.'},
#  '18458795': {'semantic': [{'operation': 'select',
#     'dependencies': [],
#     'argument': 'woman (2577566)'},
#    {'operation': 'relate',
#     'dependencies': [0],
#     'argument': 'person,to the left of,s (3624257)'},
#    {'operation': 'choose age', 'dependencies': [1], 'argument': 'young|old'}],
#   'entailed': ['18458789',
#    '18458797',
#    '18458781',
#    '18458782',
#    '18458784',
#    '18458785',
#    '18458786',
#    '18458787',
#    '18458788',
#    '18458796',
#    '18458794',
#    '18458793'],
#   'equivalent': ['18458795', '18458794'],
#   'question': 'Is the person to the left of the woman young or old?',
#   'imageId': '2345483',
#   'isBalanced': False,
#   'groups': {'global': 'age', 'local': '10c-child_age'},
#   'answer': 'young',
#   'semanticStr': 'select: woman (2577566)->relate: person,to the left of,s (3624257) [0]->choose age: young|old [1]',
#   'annotations': {'answer': {},
#    'question': {'8': '2577566', '2': '3624257'},
#    'fullAnswer': {'1': '3624257'}},
#   'types': {'detailed': 'chooseAttr',
#    'semantic': 'attr',
#    'structural': 'choose'},
#   'fullAnswer': 'The child is young.'},
#  '17336116': {'semantic': [{'operation': 'select',
#     'dependencies': [],
#     'argument': 'keyboard (1292054)'},
#    {'operation': 'relate',
#     'dependencies': [0],
#     'argument': 'phone,to the left of,s (1292060)'},
#    {'operation': 'verify color', 'dependencies': [1], 'argument': 'gray'}],
#   'entailed': ['17336118',
#    '17336119',
#    '17336120',
#    '17336129',
#    '17336121',
#    '17336112',
#    '17336113',
#    '17336114',
#    '17336115',
#    '17336117',
#    '17336123',
#    '17336122',
#    '17336130'],
#   'equivalent': ['17336115', '17336116'],
#   'question': 'Does the phone to the left of the keyboard have gray color?',
#   'imageId': '2385866',
#   'isBalanced': False,
#   'groups': {'global': None, 'local': '06-phone_gray'},
#   'answer': 'yes',
#   'semanticStr': 'select: keyboard (1292054)->relate: phone,to the left of,s (1292060) [0]->verify color: gray [1]',
#   'annotations': {'answer': {},
#    'question': {'8': '1292054', '2': '1292060'},
#    'fullAnswer': {'2': '1292060'}},
#   'types': {'detailed': 'verifyAttrK',
#    'semantic': 'attr',
#    'structural': 'verify'},
#   'fullAnswer': 'Yes, the telephone is gray.'},
#  '13598460': {'semantic': [{'operation': 'select',
#     'dependencies': [],
#     'argument': 'device (418896)'},
#    {'operation': 'filter', 'dependencies': [0], 'argument': 'not(on)'},
#    {'operation': 'choose name',
#     'dependencies': [1],
#     'argument': 'television|remote control'}],
#   'entailed': [],
#   'equivalent': ['13598460'],
#   'question': 'What device is not on, the remote or the television?',
#   'imageId': '2399127',
#   'isBalanced': False,
#   'groups': {'global': 'device', 'local': '12c-device_n#on'},
#   'answer': 'remote control',
#   'semanticStr': 'select: device (418896)->filter: not(on) [0]->choose name: television|remote control [1]',
#   'annotations': {'answer': {'0:2': '418896'},
#    'question': {'1': '418916', '9': '418916', '6': '418896'},
#    'fullAnswer': {'1': '418896'}},
#   'types': {'detailed': 'categoryThatChoose',
#    'semantic': 'cat',
#    'structural': 'choose'},
#   'fullAnswer': 'The remote is not on.'},
#  '13598461': {'semantic': [{'operation': 'select',
#     'dependencies': [],
#     'argument': 'device (418896)'},
#    {'operation': 'filter', 'dependencies': [0], 'argument': 'not(on)'},
#    {'operation': 'query', 'dependencies': [1], 'argument': 'name'}],
#   'entailed': ['13598483', '13598462'],
#   'equivalent': ['13598461'],
#   'question': 'What is the device that is not on called?',
#   'imageId': '2399127',
#   'isBalanced': True,
#   'groups': {'global': 'device', 'local': '12q-device_n#on'},
#   'answer': 'remote control',
#   'semanticStr': 'select: device (418896)->filter: not(on) [0]->query: name [1]',
#   'annotations': {'answer': {'0:2': '418896'},
#    'question': {'3': '418916'},
#    'fullAnswer': {'1': '418916', '4:6': '418896'}},
#   'types': {'detailed': 'categoryThat',
#    'semantic': 'cat',
#    'structural': 'query'},
#   'fullAnswer': 'The device is a remote control.'},
#  '13598462': {'semantic': [{'operation': 'select',
#     'dependencies': [],
#     'argument': 'device (418896)'},
#    {'operation': 'filter', 'dependencies': [0], 'argument': 'not(on)'},
#    {'operation': 'query', 'dependencies': [1], 'argument': 'name'}],
#   'entailed': ['13598483', '13598461'],
#   'equivalent': ['13598462'],
#   'question': 'What device is not on?',
#   'imageId': '2399127',
#   'isBalanced': True,
#   'groups': {'global': 'device', 'local': '12q-device_n#on'},
#   'answer': 'remote control',
#   'semanticStr': 'select: device (418896)->filter: not(on) [0]->query: name [1]',
#   'annotations': {'answer': {'0:2': '418896'},
#    'question': {'1': '418916'},
#    'fullAnswer': {'1': '418916', '4:6': '418896'}},
#   'types': {'detailed': 'categoryThat',
#    'semantic': 'cat',
#    'structural': 'query'},
#   'fullAnswer': 'The device is a remote control.'},
#  '13598463': {'semantic': [{'operation': 'select',
#     'dependencies': [],
#     'argument': 'this (418916)'},
#    {'operation': 'choose name',
#     'dependencies': [0],
#     'argument': 'television|calculator'}],
#   'entailed': [],
#   'equivalent': ['13598463'],
#   'question': 'Is this a calculator or a television?',
#   'imageId': '2399127',
#   'isBalanced': False,
#   'groups': {'global': 'device', 'local': '08oc-calculator_television'},
#   'answer': 'television',
#   'semanticStr': 'select: this (418916)->choose name: television|calculator [0]',
#   'annotations': {'answer': {'0': '418916'},
#    'question': {'6': '418916'},
#    'fullAnswer': {'3': '418916'}},
#   'types': {'detailed': 'objThisChoose',
#    'semantic': 'cat',
#    'structural': 'choose'},
#   'fullAnswer': 'This is a television.'},
#  '13598464': {'semantic': [{'operation': 'select',
#     'dependencies': [],
#     'argument': 'television (418916)'},
#    {'operation': 'filter', 'dependencies': [0], 'argument': 'not(on)'},
#    {'operation': 'exist', 'dependencies': [1], 'argument': '?'},
#    {'operation': 'select', 'dependencies': [], 'argument': 'laptop (-) '},
#    {'operation': 'filter', 'dependencies': [3], 'argument': 'not(on)'},
#    {'operation': 'exist', 'dependencies': [4], 'argument': '?'},
#    {'operation': 'or', 'dependencies': [2, 5], 'argument': ''}],
#   'entailed': ['13598475', '13598474'],
#   'equivalent': ['13598464'],
#   'question': 'Do you see televisions or laptops that are not on?',
#   'imageId': '2399127',
#   'isBalanced': False,
#   'groups': {'global': None, 'local': '04-television_n#on'},
#   'answer': 'no',
#   'semanticStr': 'select: television (418916)->filter: not(on) [0]->exist: ? [1]->select: laptop (-) ->filter: not(on) [3]->exist: ? [4]->or:  [2, 5]',
#   'annotations': {'answer': {},
#    'question': {'3': '418916'},
#    'fullAnswer': {'4': '418916'}},
#   'types': {'detailed': 'existThatOrC',
#    'semantic': 'obj',
#    'structural': 'logical'},
#   'fullAnswer': 'No, there is a television but it is on.'},
#  '13598465': {'semantic': [{'operation': 'select',
#     'dependencies': [],
#     'argument': 'television (418916)'},
#    {'operation': 'verify', 'dependencies': [0], 'argument': 'on'}],
#   'entailed': ['13598476',
#    '13598468',
#    '13598469',
#    '13598466',
#    '13598467',
#    '13598470'],
#   'equivalent': ['13598465', '13598466', '13598467'],
#   'question': 'Is the TV on?',
#   'imageId': '2399127',
#   'isBalanced': False,
#   'groups': {'global': None, 'local': '06-television_on'},
#   'answer': 'yes',
#   'semanticStr': 'select: television (418916)->verify: on [0]',
#   'annotations': {'answer': {},
#    'question': {'2': '418916'},
#    'fullAnswer': {'2': '418916'}},
#   'types': {'detailed': 'verifyAttr',
#    'semantic': 'attr',
#    'structural': 'verify'},
#   'fullAnswer': 'Yes, the TV is on.'},
#  '13598466': {'semantic': [{'operation': 'select',
#     'dependencies': [],
#     'argument': 'television (418916)'},
#    {'operation': 'verify', 'dependencies': [0], 'argument': 'on'}],
#   'entailed': ['13598476',
#    '13598468',
#    '13598469',
#    '13598467',
#    '13598465',
#    '13598470'],
#   'equivalent': ['13598465', '13598466', '13598467'],
#   'question': 'Does the TV appear to be on?',
#   'imageId': '2399127',
#   'isBalanced': False,
#   'groups': {'global': None, 'local': '06-television_on'},
#   'answer': 'yes',
#   'semanticStr': 'select: television (418916)->verify: on [0]',
#   'annotations': {'answer': {},
#    'question': {'2': '418916'},
#    'fullAnswer': {'2': '418916'}},
#   'types': {'detailed': 'verifyAttr',
#    'semantic': 'attr',
#    'structural': 'verify'},
#   'fullAnswer': 'Yes, the TV is on.'},
#  '13598467': {'semantic': [{'operation': 'select',
#     'dependencies': [],
#     'argument': 'television (418916)'},
#    {'operation': 'verify', 'dependencies': [0], 'argument': 'on'}],
#   'entailed': ['13598476',
#    '13598468',
#    '13598469',
#    '13598466',
#    '13598465',
#    '13598470'],
#   'equivalent': ['13598465', '13598466', '13598467'],
#   'question': 'Do you think the TV is on?',
#   'imageId': '2399127',
#   'isBalanced': False,
#   'groups': {'global': None, 'local': '06-television_on'},
#   'answer': 'yes',
#   'semanticStr': 'select: television (418916)->verify: on [0]',
#   'annotations': {'answer': {},
#    'question': {'4': '418916'},
#    'fullAnswer': {'2': '418916'}},
#   'types': {'detailed': 'verifyAttr',
#    'semantic': 'attr',
#    'structural': 'verify'},
#   'fullAnswer': 'Yes, the TV is on.'},
#  '13598468': {'semantic': [{'operation': 'select',
#     'dependencies': [],
#     'argument': 'television (418916)'},
#    {'operation': 'verify', 'dependencies': [0], 'argument': 'on'}],
#   'entailed': ['13598476',
#    '13598469',
#    '13598466',
#    '13598467',
#    '13598465',
#    '13598470'],
#   'equivalent': ['13598468'],
#   'question': 'Does that television seem to be on?',
#   'imageId': '2399127',
#   'isBalanced': False,
#   'groups': {'global': None, 'local': '06-television_on'},
#   'answer': 'yes',
#   'semanticStr': 'select: television (418916)->verify: on [0]',
#   'annotations': {'answer': {},
#    'question': {'2': '418916'},
#    'fullAnswer': {'2': '418916'}},
#   'types': {'detailed': 'verifyAttrK',
#    'semantic': 'attr',
#    'structural': 'verify'},
#   'fullAnswer': 'Yes, the television is on.'},
#  '13598469': {'semantic': [{'operation': 'select',
#     'dependencies': [],
#     'argument': 'television (418916)'},
#    {'operation': 'verify', 'dependencies': [0], 'argument': 'off'}],
#   'entailed': ['13598476',
#    '13598468',
#    '13598466',
#    '13598467',
#    '13598465',
#    '13598470'],
#   'equivalent': ['13598469'],
#   'question': 'Do you think that TV is off?',
#   'imageId': '2399127',
#   'isBalanced': False,
#   'groups': {'global': None, 'local': '06-television_off'},
#   'answer': 'no',
#   'semanticStr': 'select: television (418916)->verify: off [0]',
#   'annotations': {'answer': {},
#    'question': {'4': '418916'},
#    'fullAnswer': {'2': '418916'}},
#   'types': {'detailed': 'verifyAttrC',
#    'semantic': 'attr',
#    'structural': 'verify'},
#   'fullAnswer': 'No, the TV is on.'},
#  '08369250': {'semantic': [{'operation': 'select',
#     'dependencies': [],
#     'argument': 'man (2527953)'},
#    {'operation': 'relate',
#     'dependencies': [0],
#     'argument': 'bag,wearing,o (1978710)'},
#    {'operation': 'query', 'dependencies': [1], 'argument': 'name'}],
#   'entailed': ['08369321', '08369249'],
#   'equivalent': ['08369250'],
#   'question': 'Which kind of bag is the man wearing?',
#   'imageId': '2372640',
#   'isBalanced': False,
#   'groups': {'global': 'bag', 'local': '15-man_wearing,o'},
#   'answer': 'backpack',
#   'semanticStr': 'select: man (2527953)->relate: bag,wearing,o (1978710) [0]->query: name [1]',
#   'annotations': {'answer': {'0': '1978710'},
#    'question': {'3': '1978710'},
#    'fullAnswer': {'1': '2527953', '5': '1978710'}},
#   'types': {'detailed': 'categoryRelO',
#    'semantic': 'rel',
#    'structural': 'query'},
#   'fullAnswer': 'The man is wearing a backpack.'},
#  '00524220': {'semantic': [{'operation': 'select',
#     'dependencies': [],
#     'argument': 'train (2970422)'},
#    {'operation': 'relate',
#     'dependencies': [0],
#     'argument': 'phone,to the left of,s (2961206)'},
#    {'operation': 'relate',
#     'dependencies': [1],
#     'argument': 'chair,to the left of,s (-)'},
#    {'operation': 'exist', 'dependencies': [2], 'argument': '?'}],
#   'entailed': ['00524221', '00524219'],
#   'equivalent': ['00524220', '00524219'],
#   'question': 'Is there a chair to the left of the phone that is to the left of the train?',
#   'imageId': '2318853',
#   'isBalanced': False,
#   'groups': {'global': None, 'local': '13-phone_chair'},
#   'answer': 'no',
#   'semanticStr': 'select: train (2970422)->relate: phone,to the left of,s (2961206) [0]->relate: chair,to the left of,s (-) [1]->exist: ? [2]',
#   'annotations': {'answer': {},
#    'question': {'9': '2961206', '17': '2970422'},
#    'fullAnswer': {'10': '2961206', '4': '2825470'}},
#   'types': {'detailed': 'existRelSC',
#    'semantic': 'rel',
#    'structural': 'verify'},
#   'fullAnswer': 'No, there is a man to the left of the telephone.'},
#  '19799919': {'semantic': [{'operation': 'select',
#     'dependencies': [],
#     'argument': 'rug (-)'},
#    {'operation': 'exist', 'dependencies': [0], 'argument': '?'},
#    {'operation': 'select', 'dependencies': [], 'argument': 'cigarette (-) '},
#    {'operation': 'exist', 'dependencies': [2], 'argument': '?'},
#    {'operation': 'or', 'dependencies': [1, 3], 'argument': ''}],
#   'entailed': ['19799918'],
#   'equivalent': ['19799919'],
#   'question': 'Are there any cigarettes or rugs in the picture?',
#   'imageId': '2401360',
#   'isBalanced': False,
#   'groups': {'global': None, 'local': '09existOr-cigarette_rug'},
#   'answer': 'no',
#   'semanticStr': 'select: rug (-)->exist: ? [0]->select: cigarette (-) ->exist: ? [2]->or:  [1, 3]',
#   'annotations': {'answer': {}, 'question': {}, 'fullAnswer': {}},
#   'types': {'detailed': 'existOrC',
#    'semantic': 'obj',
#    'structural': 'logical'},
#   'fullAnswer': 'No, there are no cigarettes or rugs.'},
#  '04819668': {'semantic': [{'operation': 'select',
#     'dependencies': [],
#     'argument': 'bedspread (3822871)'},
#    {'operation': 'relate',
#     'dependencies': [0],
#     'argument': 'furniture,to the right of,s (3717928)'},
#    {'operation': 'query', 'dependencies': [1], 'argument': 'name'}],
#   'entailed': ['04819626', '04819672', '04819671', '04819670', '04819669'],
#   'equivalent': ['04819668', '04819669'],
#   'question': 'What kind of furniture is to the right of the bedspread?',
#   'imageId': '4912',
#   'isBalanced': False,
#   'groups': {'global': 'furniture', 'local': '15-bedspread_to the right of,s'},
#   'answer': 'cabinet',
#   'semanticStr': 'select: bedspread (3822871)->relate: furniture,to the right of,s (3717928) [0]->query: name [1]',
#   'annotations': {'answer': {'0': '3717928'},
#    'question': {'10': '3822871', '3': '3717928'},
#    'fullAnswer': {'1:4': '3717928', '6': '3717928'}},
#   'types': {'detailed': 'categoryRelS',
#    'semantic': 'rel',
#    'structural': 'query'},
#   'fullAnswer': 'The piece of furniture is a cabinet.'},
#  '04819669': {'semantic': [{'operation': 'select',
#     'dependencies': [],
#     'argument': 'bedspread (3822871)'},
#    {'operation': 'relate',
#     'dependencies': [0],
#     'argument': 'furniture,to the right of,s (3717928)'},
#    {'operation': 'query', 'dependencies': [1], 'argument': 'name'}],
#   'entailed': ['04819626', '04819672', '04819671', '04819670', '04819668'],
#   'equivalent': ['04819668', '04819669'],
#   'question': 'What is the item of furniture that is to the right of the bedspread?',
#   'imageId': '4912',
#   'isBalanced': False,
#   'groups': {'global': 'furniture', 'local': '15-bedspread_to the right of,s'},
#   'answer': 'cabinet',
#   'semanticStr': 'select: bedspread (3822871)->relate: furniture,to the right of,s (3717928) [0]->query: name [1]',
#   'annotations': {'answer': {'0': '3717928'},
#    'question': {'13': '3822871', '3:6': '3717928'},
#    'fullAnswer': {'1:4': '3717928', '6': '3717928'}},
#   'types': {'detailed': 'categoryRelS',
#    'semantic': 'rel',
#    'structural': 'query'},
#   'fullAnswer': 'The piece of furniture is a cabinet.'},
#  '04819666': {'semantic': [{'operation': 'select',
#     'dependencies': [],
#     'argument': 'bed (3693001)'},
#    {'operation': 'relate',
#     'dependencies': [0],
#     'argument': 'drawer,to the right of,s (-)'},
#    {'operation': 'exist', 'dependencies': [1], 'argument': '?'}],
#   'entailed': ['04819667'],
#   'equivalent': ['04819666', '04819667'],
#   'question': 'Are there drawers to the right of the bed?',
#   'imageId': '4912',
#   'isBalanced': False,
#   'groups': {'global': None, 'local': '13-bed_drawer'},
#   'answer': 'no',
#   'semanticStr': 'select: bed (3693001)->relate: drawer,to the right of,s (-) [0]->exist: ? [1]',
#   'annotations': {'answer': {},
#    'question': {'8': '3693001'},
#    'fullAnswer': {'10': '3693001', '4': '3717928'}},
#   'types': {'detailed': 'existRelSC',
#    'semantic': 'rel',
#    'structural': 'verify'},
#   'fullAnswer': 'No, there is a cabinet to the right of the bed.'},
#  '04819667': {'semantic': [{'operation': 'select',
#     'dependencies': [],
#     'argument': 'bed (3693001)'},
#    {'operation': 'relate',
#     'dependencies': [0],
#     'argument': 'drawer,to the right of,s (-)'},
#    {'operation': 'exist', 'dependencies': [1], 'argument': '?'}],
#   'entailed': ['04819666'],
#   'equivalent': ['04819666', '04819667'],
#   'question': 'Do you see drawers to the right of the bed?',
#   'imageId': '4912',
#   'isBalanced': False,
#   'groups': {'global': None, 'local': '13-bed_drawer'},
#   'answer': 'no',
#   'semanticStr': 'select: bed (3693001)->relate: drawer,to the right of,s (-) [0]->exist: ? [1]',
#   'annotations': {'answer': {},
#    'question': {'9': '3693001'},
#    'fullAnswer': {'10': '3693001', '4': '3717928'}},
#   'types': {'detailed': 'existRelSC',
#    'semantic': 'rel',
#    'structural': 'verify'},
#   'fullAnswer': 'No, there is a cabinet to the right of the bed.'},
#  '04819664': {'semantic': [{'operation': 'select',
#     'dependencies': [],
#     'argument': 'lamp (1564431)'},
#    {'operation': 'relate',
#     'dependencies': [0],
#     'argument': 'bed,on the side of,o (3693001)'},
#    {'operation': 'relate',
#     'dependencies': [1],
#     'argument': 'cabinet,to the right of,s (3717928)'},
#    {'operation': 'exist', 'dependencies': [2], 'argument': '?'}],
#   'entailed': ['04819578', '04819626', '04819577', '04819665', '04819663'],
#   'equivalent': ['04819664', '04819663'],
#   'question': 'Do you see a cabinet to the right of the bed the lamp is on the side of?',
#   'imageId': '4912',
#   'isBalanced': False,
#   'groups': {'global': None, 'local': '13-bed_cabinet'},
#   'answer': 'yes',
#   'semanticStr': 'select: lamp (1564431)->relate: bed,on the side of,o (3693001) [0]->relate: cabinet,to the right of,s (3717928) [1]->exist: ? [2]',
#   'annotations': {'answer': {},
#    'question': {'10': '3693001', '12': '1564431', '4': '3717928'},
#    'fullAnswer': {'10': '3693001', '4': '3717928'}},
#   'types': {'detailed': 'existRelS',
#    'semantic': 'rel',
#    'structural': 'verify'},
#   'fullAnswer': 'Yes, there is a cabinet to the right of the bed.'},
#  '04819665': {'semantic': [{'operation': 'select',
#     'dependencies': [],
#     'argument': 'bed (3693001)'},
#    {'operation': 'filter color', 'dependencies': [0], 'argument': 'white'},
#    {'operation': 'relate',
#     'dependencies': [1],
#     'argument': 'cabinet,to the left of,s (3717928)'},
#    {'operation': 'exist', 'dependencies': [2], 'argument': '?'}],
#   'entailed': [],
#   'equivalent': ['04819665'],
#   'question': 'Are there any cabinets to the left of the white bed?',
#   'imageId': '4912',
#   'isBalanced': False,
#   'groups': {'global': None, 'local': '13-bed_cabinet'},
#   'answer': 'no',
#   'semanticStr': 'select: bed (3693001)->filter color: white [0]->relate: cabinet,to the left of,s (3717928) [1]->exist: ? [2]',
#   'annotations': {'answer': {},
#    'question': {'3': '3717928', '9:11': '3693001'},
#    'fullAnswer': {'9': '3693001', '2': '3717928'}},
#   'types': {'detailed': 'existRelSRC',
#    'semantic': 'rel',
#    'structural': 'verify'},
#   'fullAnswer': 'No, the cabinet is to the right of the bed.'},
#  '04819662': {'semantic': [{'operation': 'select',
#     'dependencies': [],
#     'argument': 'bed (3693001)'},
#    {'operation': 'relate',
#     'dependencies': [0],
#     'argument': 'furniture,to the right of,s (3717928)'},
#    {'operation': 'query', 'dependencies': [1], 'argument': 'name'}],
#   'entailed': ['04819578',
#    '04819626',
#    '04819577',
#    '04819664',
#    '04819665',
#    '04819661',
#    '04819663'],
#   'equivalent': ['04819662'],
#   'question': 'What kind of furniture is to the right of the bed?',
#   'imageId': '4912',
#   'isBalanced': True,
#   'groups': {'global': 'furniture', 'local': '15-bed_to the right of,s'},
#   'answer': 'cabinet',
#   'semanticStr': 'select: bed (3693001)->relate: furniture,to the right of,s (3717928) [0]->query: name [1]',
#   'annotations': {'answer': {'0': '3717928'},
#    'question': {'3': '3717928'},
#    'fullAnswer': {'1:4': '3717928', '6': '3717928'}},
#   'types': {'detailed': 'categoryRelS',
#    'semantic': 'rel',
# ...
#     'dependencies': [],
#     'argument': 'desk (916146)'},
#    {'operation': 'relate',
#     'dependencies': [0],
#     'argument': 'animal,on,s (916145)'},
#    {'operation': 'verify color', 'dependencies': [1], 'argument': 'brown'}],
#   'entailed': ['13766858',
#    '13766859',
#    '13766860',
#    '13766871',
#    '13766850',
#    '13766851',
#    '13766853',
#    '13766872',
#    '13766855',
#    '13766856',
#    '13766857',
#    '13766870',
#    '13766861',
#    '13766873',
#    '13766862',
#    '13766869',
#    '13766849',
#    '13766854'],
#   'equivalent': ['13766852', '13766853'],
#   'question': 'Does the animal on the desk look brown?',
#   'imageId': '2344346',
#   'isBalanced': False,
#   'groups': {'global': None, 'local': '06-cat_brown'},
#   'answer': 'yes',
#   'semanticStr': 'select: desk (916146)->relate: animal,on,s (916145) [0]->verify color: brown [1]',
#   'annotations': {'answer': {},
#    'question': {'2': '916145', '5': '916146'},
#    'fullAnswer': {'2': '916145'}},
#   'types': {'detailed': 'verifyAttrK',
#    'semantic': 'attr',
#    'structural': 'verify'},
#   'fullAnswer': 'Yes, the cat is brown.'},
#  '15804343': {'semantic': [{'operation': 'select',
#     'dependencies': [],
#     'argument': 'purse (984244)'},
#    {'operation': 'choose hposition',
#     'dependencies': [0],
#     'argument': 'left|right'}],
#   'entailed': ['15804345', '15804344', '15804341', '15804342'],
#   'equivalent': ['15804344', '15804343'],
#   'question': 'Is the purse on the left or on the right?',
#   'imageId': '2325937',
#   'isBalanced': True,
#   'groups': {'global': None, 'local': '10c-purse_hposition'},
#   'answer': 'left',
#   'semanticStr': 'select: purse (984244)->choose hposition: left|right [0]',
#   'annotations': {'answer': {},
#    'question': {'2': '984244'},
#    'fullAnswer': {'1': '984244'}},
#   'types': {'detailed': 'positionChoose',
#    'semantic': 'attr',
#    'structural': 'choose'},
#   'fullAnswer': 'The purse is on the left of the image.'},
#  '06837902': {'semantic': [{'operation': 'select',
#     'dependencies': [],
#     'argument': 'car (-)'},
#    {'operation': 'exist', 'dependencies': [0], 'argument': '?'},
#    {'operation': 'select', 'dependencies': [], 'argument': 'fence (-) '},
#    {'operation': 'exist', 'dependencies': [2], 'argument': '?'},
#    {'operation': 'or', 'dependencies': [1, 3], 'argument': ''}],
#   'entailed': ['06837905',
#    '06837904',
#    '06837901',
#    '06837903',
#    '06837929',
#    '06837927',
#    '06837928',
#    '06837930',
#    '06837947',
#    '06838018',
#    '06837948'],
#   'equivalent': ['06837903', '06837902'],
#   'question': 'Are there cars or fences?',
#   'imageId': '2362425',
#   'isBalanced': False,
#   'groups': {'global': None, 'local': '09existOr-car_fence'},
#   'answer': 'no',
#   'semanticStr': 'select: car (-)->exist: ? [0]->select: fence (-) ->exist: ? [2]->or:  [1, 3]',
#   'annotations': {'answer': {}, 'question': {}, 'fullAnswer': {}},
#   'types': {'detailed': 'existOrC',
#    'semantic': 'obj',
#    'structural': 'logical'},
#   'fullAnswer': 'No, there are no fences or cars.'},
#  '13766850': {'semantic': [{'operation': 'select',
#     'dependencies': [],
#     'argument': 'desk (916146)'},
#    {'operation': 'relate',
#     'dependencies': [0],
#     'argument': 'cat,on,s (916145)'},
#    {'operation': 'verify color', 'dependencies': [1], 'argument': 'brown'}],
#   'entailed': ['13766858',
#    '13766859',
#    '13766860',
#    '13766871',
#    '13766851',
#    '13766852',
#    '13766853',
#    '13766872',
#    '13766855',
#    '13766856',
#    '13766857',
#    '13766870',
#    '13766861',
#    '13766873',
#    '13766862',
#    '13766869',
#    '13766849',
#    '13766854'],
#   'equivalent': ['13766850', '13766851'],
#   'question': 'Does the cat on the desk look brown?',
#   'imageId': '2344346',
#   'isBalanced': False,
#   'groups': {'global': None, 'local': '06-cat_brown'},
#   'answer': 'yes',
#   'semanticStr': 'select: desk (916146)->relate: cat,on,s (916145) [0]->verify color: brown [1]',
#   'annotations': {'answer': {},
#    'question': {'2': '916145', '5': '916146'},
#    'fullAnswer': {'2': '916145'}},
#   'types': {'detailed': 'verifyAttrK',
#    'semantic': 'attr',
#    'structural': 'verify'},
#   'fullAnswer': 'Yes, the cat is brown.'},
#  '13766851': {'semantic': [{'operation': 'select',
#     'dependencies': [],
#     'argument': 'desk (916146)'},
#    {'operation': 'relate',
#     'dependencies': [0],
#     'argument': 'cat,on,s (916145)'},
#    {'operation': 'verify color', 'dependencies': [1], 'argument': 'brown'}],
#   'entailed': ['13766858',
#    '13766859',
#    '13766860',
#    '13766871',
#    '13766850',
#    '13766852',
#    '13766853',
#    '13766872',
#    '13766855',
#    '13766856',
#    '13766857',
#    '13766870',
#    '13766861',
#    '13766873',
#    '13766862',
#    '13766869',
#    '13766849',
#    '13766854'],
#   'equivalent': ['13766850', '13766851'],
#   'question': 'Does the cat on the desk have brown color?',
#   'imageId': '2344346',
#   'isBalanced': False,
#   'groups': {'global': None, 'local': '06-cat_brown'},
#   'answer': 'yes',
#   'semanticStr': 'select: desk (916146)->relate: cat,on,s (916145) [0]->verify color: brown [1]',
#   'annotations': {'answer': {},
#    'question': {'2': '916145', '5': '916146'},
#    'fullAnswer': {'2': '916145'}},
#   'types': {'detailed': 'verifyAttrK',
#    'semantic': 'attr',
#    'structural': 'verify'},
#   'fullAnswer': 'Yes, the cat is brown.'},
#  '151049985': {'semantic': [{'operation': 'select',
#     'dependencies': [],
#     'argument': 'pillow (4167680)'},
#    {'operation': 'exist', 'dependencies': [0], 'argument': '?'},
#    {'operation': 'select', 'dependencies': [], 'argument': 'light bulb (-) '},
#    {'operation': 'exist', 'dependencies': [2], 'argument': '?'},
#    {'operation': 'or', 'dependencies': [1, 3], 'argument': ''}],
#   'entailed': ['151049986'],
#   'equivalent': ['151049986', '151049985'],
#   'question': 'Are there either pillows or bulbs?',
#   'imageId': '2322576',
#   'isBalanced': False,
#   'groups': {'global': None, 'local': '09existOr-light bulb_pillow'},
#   'answer': 'yes',
#   'semanticStr': 'select: pillow (4167680)->exist: ? [0]->select: light bulb (-) ->exist: ? [2]->or:  [1, 3]',
#   'annotations': {'answer': {},
#    'question': {'3': '4167680'},
#    'fullAnswer': {'4': '4167680'}},
#   'types': {'detailed': 'existOr', 'semantic': 'obj', 'structural': 'logical'},
#   'fullAnswer': 'Yes, there is a pillow.'},
#  '1124550': {'semantic': [{'operation': 'select',
#     'dependencies': [],
#     'argument': 'child (734774)'},
#    {'operation': 'relate',
#     'dependencies': [0],
#     'argument': 'vehicle,to the right of,s (734769)'},
#    {'operation': 'query', 'dependencies': [1], 'argument': 'color'}],
#   'entailed': ['1124560',
#    '1124551',
#    '1124553',
#    '1124552',
#    '1124546',
#    '1124547',
#    '1124559',
#    '1124548',
#    '1124549'],
#   'equivalent': ['1124550'],
#   'question': 'What color is the vehicle to the right of the kid?',
#   'imageId': '2372946',
#   'isBalanced': False,
#   'groups': {'global': 'color', 'local': '10q-train_color'},
#   'answer': 'green',
#   'semanticStr': 'select: child (734774)->relate: vehicle,to the right of,s (734769) [0]->query: color [1]',
#   'annotations': {'answer': {},
#    'question': {'10': '734774', '4': '734769'},
#    'fullAnswer': {'1': '734769'}},
#   'types': {'detailed': 'directOf', 'semantic': 'attr', 'structural': 'query'},
#   'fullAnswer': 'The train is green.'},
#  '18861349': {'semantic': [{'operation': 'select',
#     'dependencies': [],
#     'argument': 'counter (4413959)'},
#    {'operation': 'relate',
#     'dependencies': [0],
#     'argument': 'sink,on,s (4413958)'},
#    {'operation': 'query', 'dependencies': [1], 'argument': 'color'}],
#   'entailed': ['18861346',
#    '18861347',
#    '18861348',
#    '18861352',
#    '18861351',
#    '18861350'],
#   'equivalent': ['18861349'],
#   'question': 'What color do you think is the sink on the counter?',
#   'imageId': '286061',
#   'isBalanced': False,
#   'groups': {'global': 'color', 'local': '10q-sink_color'},
#   'answer': 'white',
#   'semanticStr': 'select: counter (4413959)->relate: sink,on,s (4413958) [0]->query: color [1]',
#   'annotations': {'answer': {},
#    'question': {'10': '4413959', '7': '4413958'},
#    'fullAnswer': {'1': '4413958'}},
#   'types': {'detailed': 'directOf', 'semantic': 'attr', 'structural': 'query'},
#   'fullAnswer': 'The sink is white.'},
#  '19225718': {'semantic': [{'operation': 'select',
#     'dependencies': [],
#     'argument': 'counter (936881)'},
#    {'operation': 'relate',
#     'dependencies': [0],
#     'argument': 'appliance,next to,s (936898)'},
#    {'operation': 'relate',
#     'dependencies': [1],
#     'argument': 'cup,to the left of,s (-)'},
#    {'operation': 'exist', 'dependencies': [2], 'argument': '?'}],
#   'entailed': ['19225717', '19225716'],
#   'equivalent': ['19225717', '19225718'],
#   'question': 'Are there any cups to the left of the appliance next to the counter?',
#   'imageId': '2342134',
#   'isBalanced': False,
#   'groups': {'global': None, 'local': '13-refrigerator_cup'},
#   'answer': 'no',
#   'semanticStr': 'select: counter (936881)->relate: appliance,next to,s (936898) [0]->relate: cup,to the left of,s (-) [1]->exist: ? [2]',
#   'annotations': {'answer': {},
#    'question': {'9': '936898', '13': '936881'},
#    'fullAnswer': {'10': '936898', '4': '936890'}},
#   'types': {'detailed': 'existRelSC',
#    'semantic': 'rel',
#    'structural': 'verify'},
#   'fullAnswer': 'No, there is a plate to the left of the freezer.'},
#  '15804342': {'semantic': [{'operation': 'select',
#     'dependencies': [],
#     'argument': 'purse (984244)'},
#    {'operation': 'verify hposition',
#     'dependencies': [0],
#     'argument': 'right'}],
#   'entailed': ['15804345', '15804344', '15804341', '15804343'],
#   'equivalent': ['15804342'],
#   'question': 'Is the purse on the right of the photo?',
#   'imageId': '2325937',
#   'isBalanced': False,
#   'groups': {'global': None, 'local': '06-purse_right'},
#   'answer': 'no',
#   'semanticStr': 'select: purse (984244)->verify hposition: right [0]',
#   'annotations': {'answer': {},
#    'question': {'2': '984244'},
#    'fullAnswer': {'2': '984244'}},
#   'types': {'detailed': 'positionVerifyC',
#    'semantic': 'attr',
#    'structural': 'verify'},
#   'fullAnswer': 'No, the purse is on the left of the image.'},
#  '124604': {'semantic': [{'operation': 'select',
#     'dependencies': [],
#     'argument': 'door (2853355)'},
#    {'operation': 'exist', 'dependencies': [0], 'argument': '?'},
#    {'operation': 'select',
#     'dependencies': [],
#     'argument': 'mirror (2981413) '},
#    {'operation': 'exist', 'dependencies': [2], 'argument': '?'},
#    {'operation': 'or', 'dependencies': [1, 3], 'argument': ''}],
#   'entailed': ['124605'],
#   'equivalent': ['124604', '124605'],
#   'question': 'Is there either a mirror or a door in this photo?',
#   'imageId': '2378417',
#   'isBalanced': False,
#   'groups': {'global': None, 'local': '09existOr-door_mirror'},
#   'answer': 'yes',
#   'semanticStr': 'select: door (2853355)->exist: ? [0]->select: mirror (2981413) ->exist: ? [2]->or:  [1, 3]',
#   'annotations': {'answer': {},
#    'question': {'4': '2981413', '7': '2853355'},
#    'fullAnswer': {'4': '2853355'}},
#   'types': {'detailed': 'existOr', 'semantic': 'obj', 'structural': 'logical'},
#   'fullAnswer': 'Yes, there is a door.'},
#  '04916311': {'semantic': [{'operation': 'select',
#     'dependencies': [],
#     'argument': 'elephant (-)'},
#    {'operation': 'exist', 'dependencies': [0], 'argument': '?'}],
#   'entailed': [],
#   'equivalent': ['04916311'],
#   'question': 'Are there elephants?',
#   'imageId': '2380181',
#   'isBalanced': False,
#   'groups': {'global': None, 'local': '03-elephant'},
#   'answer': 'no',
#   'semanticStr': 'select: elephant (-)->exist: ? [0]',
#   'annotations': {'answer': {}, 'question': {}, 'fullAnswer': {}},
#   'types': {'detailed': 'existC', 'semantic': 'obj', 'structural': 'verify'},
#   'fullAnswer': 'No, there are no elephants.'},
#  '09313578': {'semantic': [{'operation': 'select',
#     'dependencies': [],
#     'argument': 'bottle (3561821)'},
#    {'operation': 'relate',
#     'dependencies': [0],
#     'argument': 'boy,to the left of,s (1675380)'},
#    {'operation': 'exist', 'dependencies': [1], 'argument': '?'}],
#   'entailed': ['09313577', '09313582', '09313580', '09313581', '09313579'],
#   'equivalent': ['09313577', '09313578'],
#   'question': 'Do you see any boys to the left of the bottle in the image?',
#   'imageId': '2356493',
#   'isBalanced': False,
#   'groups': {'global': None, 'local': '13-bottle_boy'},
#   'answer': 'yes',
#   'semanticStr': 'select: bottle (3561821)->relate: boy,to the left of,s (1675380) [0]->exist: ? [1]',
#   'annotations': {'answer': {},
#    'question': {'10': '3561821', '4': '1675380'},
#    'fullAnswer': {'10': '3561821', '4': '1675380'}},
#   'types': {'detailed': 'existRelS',
#    'semantic': 'rel',
#    'structural': 'verify'},
#   'fullAnswer': 'Yes, there is a boy to the left of the bottle.'},
#  '17639639': {'semantic': [{'operation': 'select',
#     'dependencies': [],
#     'argument': 'lamp (3202279)'},
#    {'operation': 'verify color', 'dependencies': [0], 'argument': 'black'}],
#   'entailed': ['17639644', '17639638'],
#   'equivalent': ['17639639'],
#   'question': 'Does the lamp look black?',
#   'imageId': '2405707',
#   'isBalanced': False,
#   'groups': {'global': None, 'local': '06-lamp_black'},
#   'answer': 'no',
#   'semanticStr': 'select: lamp (3202279)->verify color: black [0]',
#   'annotations': {'answer': {},
#    'question': {'2': '3202279'},
#    'fullAnswer': {'2': '3202279'}},
#   'types': {'detailed': 'verifyAttrKC',
#    'semantic': 'attr',
#    'structural': 'verify'},
#   'fullAnswer': 'No, the lamp is gold.'},
#  '17639638': {'semantic': [{'operation': 'select',
#     'dependencies': [],
#     'argument': 'lamp (3202279)'},
#    {'operation': 'verify color', 'dependencies': [0], 'argument': 'black'}],
#   'entailed': ['17639644', '17639639'],
#   'equivalent': ['17639638'],
#   'question': 'Is the lamp black?',
#   'imageId': '2405707',
#   'isBalanced': False,
#   'groups': {'global': None, 'local': '06-lamp_black'},
#   'answer': 'no',
#   'semanticStr': 'select: lamp (3202279)->verify color: black [0]',
#   'annotations': {'answer': {},
#    'question': {'2': '3202279'},
#    'fullAnswer': {'2': '3202279'}},
#   'types': {'detailed': 'verifyAttrC',
#    'semantic': 'attr',
#    'structural': 'verify'},
#   'fullAnswer': 'No, the lamp is gold.'},
#  '09313579': {'semantic': [{'operation': 'select',
#     'dependencies': [],
#     'argument': 'bench (2174533)'},
#    {'operation': 'relate',
#     'dependencies': [0],
#     'argument': 'bottle,on,s (3561821)'},
#    {'operation': 'relate',
#     'dependencies': [1],
#     'argument': 'boy,to the left of,s (1675380)'},
#    {'operation': 'exist', 'dependencies': [2], 'argument': '?'}],
#   'entailed': ['09313577', '09313582', '09313580', '09313581', '09313578'],
#   'equivalent': ['09313579'],
#   'question': 'Are there boys to the left of the bottle that is on the bench?',
#   'imageId': '2356493',
#   'isBalanced': False,
#   'groups': {'global': None, 'local': '13-bottle_boy'},
#   'answer': 'yes',
#   'semanticStr': 'select: bench (2174533)->relate: bottle,on,s (3561821) [0]->relate: boy,to the left of,s (1675380) [1]->exist: ? [2]',
#   'annotations': {'answer': {},
#    'question': {'8': '3561821', '13': '2174533', '2': '1675380'},
#    'fullAnswer': {'10': '3561821', '4': '1675380'}},
#   'types': {'detailed': 'existRelS',
#    'semantic': 'rel',
#    'structural': 'verify'},
#   'fullAnswer': 'Yes, there is a boy to the left of the bottle.'},
#  '17639635': {'semantic': [{'operation': 'select',
#     'dependencies': [],
#     'argument': 'lamp (3202279)'},
#    {'operation': 'verify color', 'dependencies': [0], 'argument': 'gold'}],
#   'entailed': ['17639637', '17639636', '17639644', '17639639', '17639638'],
#   'equivalent': ['17639635'],
#   'question': 'Is the lamp gold?',
#   'imageId': '2405707',
#   'isBalanced': False,
#   'groups': {'global': None, 'local': '06-lamp_gold'},
#   'answer': 'yes',
#   'semanticStr': 'select: lamp (3202279)->verify color: gold [0]',
#   'annotations': {'answer': {},
#    'question': {'2': '3202279'},
#    'fullAnswer': {'2': '3202279'}},
#   'types': {'detailed': 'verifyAttr',
#    'semantic': 'attr',
#    'structural': 'verify'},
#   'fullAnswer': 'Yes, the lamp is gold.'},
#  ...}

# %%
filename
# Out:
# '../vqa_diag/questions1.2/train_all_questions/train_all_questions_1.json'
